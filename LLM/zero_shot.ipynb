# %%
from transformers import AutoModel,LlamaTokenizer,LlamaConfig,LlamaForCausalLM,AutoTokenizer,AutoModelForCausalLM,AutoConfig,GenerationConfig
import torch
import json
from transformers import AutoTokenizer
import pandas as pd
from config import *
from pathlib import Path
from string import Template
from tqdm import tqdm

model = AutoModelForCausalLM.from_pretrained(model_name,torch_dtype=torch.bfloat16,trust_remote_code=True,proxies=proxies , use_auth_token=hf_token , cache_dir=cache_dir , device_map='auto')
tokenizer = AutoTokenizer.from_pretrained(model_name,proxies=proxies , use_auth_token=hf_token , cache_dir=cache_dir)
test_set = json.load(open('../vul4c_dataset/test.json',mode='r'))
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]

# %%
small_test_set = list(filter(lambda x:len(x['func'].splitlines()) < 30 , test_set))

small_test_set_df = pd.DataFrame(small_test_set)
small_test_set_df[small_test_set_df['vul'] == 1].to_dict('records')
# Out:
# [{'cve': 'CVE-2016-6663',
#   'cwe_list': ['CWE-362'],
#   'repo_name': 'MariaDB/server',
#   'commit_hash': '347eeefbfc658c8531878218487d729f4e020805',
#   'git_url': 'https://github.com/MariaDB/server/commit/347eeefbfc658c8531878218487d729f4e020805',
#   'func': 'int my_redel(const char *org_name, const char *tmp_name,\n             time_t backup_time_stamp, myf MyFlags)\n{\n  int error=1;\n  DBUG_ENTER("my_redel");\n  DBUG_PRINT("my",("org_name: \'%s\' tmp_name: \'%s\'  MyFlags: %d",\n\t\t   org_name,tmp_name,MyFlags));\n\n  if (my_copystat(org_name,tmp_name,MyFlags) < 0)\n    goto end;\n  if (MyFlags & MY_REDEL_MAKE_BACKUP)\n  {\n    char name_buff[FN_REFLEN + MY_BACKUP_NAME_EXTRA_LENGTH];    \n    my_create_backup_name(name_buff, org_name, backup_time_stamp);\n    if (my_rename(org_name, name_buff, MyFlags))\n      goto end;\n  }\n  else if (my_delete(org_name, MyFlags))\n      goto end;\n  if (my_rename(tmp_name,org_name,MyFlags))\n    goto end;\n\n  error=0;\nend:\n  DBUG_RETURN(error);\n}',
#   'graph_idx': 153614,
#   'vul': 1,
#   'id': 69},
#  {'cve': 'CVE-2018-20742',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'ucbrise/opaque',
#   'commit_hash': '5ddda15d89f5ac82f4416208c5319ace4aecdc36',
#   'git_url': 'https://github.com/ucbrise/opaque/commit/5ddda15d89f5ac82f4416208c5319ace4aecdc36',
#   'func': 'void ecall_scan_collect_last_primary(uint8_t *join_expr, size_t join_expr_length,\n                                     uint8_t *input_rows, size_t input_rows_length,\n                                     uint8_t **output_rows, size_t *output_rows_length) {\n  try {\n    scan_collect_last_primary(join_expr, join_expr_length,\n                              input_rows, input_rows_length,\n                              output_rows, output_rows_length);\n  } catch (const std::runtime_error &e) {\n    ocall_throw(e.what());\n  }\n}',
#   'graph_idx': 244002,
#   'vul': 1,
#   'id': 215},
#  {'cve': 'CVE-2021-44078',
#   'cwe_list': ['CWE-697'],
#   'repo_name': 'unicorn-engine/unicorn',
#   'commit_hash': 'c733bbada356b0373fa8aa72c044574bb855fd24',
#   'git_url': 'https://github.com/unicorn-engine/unicorn/commit/c733bbada356b0373fa8aa72c044574bb855fd24',
#   'func': 'static void uc_invalidate_tb(struct uc_struct *uc, uint64_t start_addr, size_t len) \n{\n    tb_page_addr_t start, end;\n\n    // GVA to GPA (GPA -> HVA via page_find, HVA->HPA via host mmu)\n    start = get_page_addr_code(uc->cpu->env_ptr, start_addr) & (target_ulong)(-1);\n    \n    // For 32bit target.\n    end = (start + len) & (target_ulong)(-1);\n\n    // We get a wrap?\n    if (start > end) {\n        return;\n    }\n\n    tb_invalidate_phys_range(uc, start, end);\n}',
#   'graph_idx': 346914,
#   'vul': 1,
#   'id': 311},
#  {'cve': 'CVE-2015-5070',
#   'cwe_list': ['CWE-200'],
#   'repo_name': 'wesnoth',
#   'commit_hash': 'b2738ffb2fdd2550ececb74f76f75583c43c8b59',
#   'git_url': 'https://github.com/wesnoth/wesnoth/commit/b2738ffb2fdd2550ececb74f76f75583c43c8b59',
#   'func': 'static bool is_legal_file(const std::string &filename)\n{\n\tDBG_FS << "Looking for \'" << filename << "\'.\\n";\n\n\tif (filename.empty()) {\n\t\tLOG_FS << "  invalid filename\\n";\n\t\treturn false;\n\t}\n\n\tif (filename.find("..") != std::string::npos) {\n\t\tERR_FS << "Illegal path \'" << filename << "\' (\\"..\\" not allowed).\\n";\n\t\treturn false;\n\t}\n\n\tif (ends_with(filename, ".pbl")) {\n\t\tERR_FS << "Illegal path \'" << filename << "\' (.pbl files are not allowed)." << std::endl;\n\t\treturn false;\n\t}\n\n\treturn true;\n}',
#   'graph_idx': 196759,
#   'vul': 1,
#   'id': 313},
#  {'cve': 'CVE-2016-9395',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'mdadams/jasper',
#   'commit_hash': 'd42b2388f7f8e0332c846675133acea151fc557a',
#   'git_url': 'https://github.com/mdadams/jasper/commit/d42b2388f7f8e0332c846675133acea151fc557a',
#   'func': 'int bmp_validate(jas_stream_t *in)\n{\n\tint n;\n\tint i;\n\tuchar buf[2];\n\n\tassert(JAS_STREAM_MAXPUTBACK >= 2);\n\n\t/* Read the first two characters that constitute the signature. */\n\tif ((n = jas_stream_read(in, (char *) buf, 2)) < 0) {\n\t\treturn -1;\n\t}\n\t/* Put the characters read back onto the stream. */\n\tfor (i = n - 1; i >= 0; --i) {\n\t\tif (jas_stream_ungetc(in, buf[i]) == EOF) {\n\t\t\treturn -1;\n\t\t}\n\t}\n\t/* Did we read enough characters? */\n\tif (n < 2) {\n\t\treturn -1;\n\t}\n\t/* Is the signature correct for the BMP format? */\n\tif (buf[0] == (BMP_MAGIC & 0xff) && buf[1] == (BMP_MAGIC >> 8)) {\n\t\treturn 0;\n\t}\n\treturn -1;\n}',
#   'graph_idx': 169461,
#   'vul': 1,
#   'id': 362},
#  {'cve': 'CVE-2016-1710',
#   'cwe_list': ['CWE-285'],
#   'repo_name': 'chromium',
#   'commit_hash': '25a8ae78165cd8725465d26e02a342d7121c42f4',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/25a8ae78165cd8725465d26e02a342d7121c42f4',
#   'func': 'Page* ChromeClientImpl::createWindow(LocalFrame* frame, const FrameLoadRequest& r, const WindowFeatures& features,\n    NavigationPolicy navigationPolicy)\n{\n    if (!m_webView->client())\n        return nullptr;\n\n    WebNavigationPolicy policy = effectiveNavigationPolicy(navigationPolicy, features);\n    DCHECK(frame->document());\n    Fullscreen::fullyExitFullscreen(*frame->document());\n\n    WebViewImpl* newView = toWebViewImpl(\n        m_webView->client()->createView(WebLocalFrameImpl::fromFrame(frame), WrappedResourceRequest(r.resourceRequest()), features, r.frameName(), policy, r.getShouldSetOpener() == NeverSetOpener || features.noopener));\n    if (!newView)\n        return nullptr;\n    return newView->page();\n}',
#   'graph_idx': 131856,
#   'vul': 1,
#   'id': 366},
#  {'cve': 'CVE-2015-8324',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '744692dc059845b2a3022119871846e74d4f6e11',
#   'git_url': 'https://github.com/torvalds/linux/commit/744692dc059845b2a3022119871846e74d4f6e11',
#   'func': 'static void ext4_end_io_work(struct work_struct *work)\n{\n\text4_io_end_t *io  = container_of(work, ext4_io_end_t, work);\n\tstruct inode *inode = io->inode;\n\tint ret = 0;\n\n\tmutex_lock(&inode->i_mutex);\n\tret = ext4_end_io_nolock(io);\n\tif (ret >= 0) {\n\t\tif (!list_empty(&io->list))\n\t\t\tlist_del_init(&io->list);\n\t\text4_free_io_end(io);\n\t}\n\tmutex_unlock(&inode->i_mutex);\n}',
#   'graph_idx': 116306,
#   'vul': 1,
#   'id': 411},
#  {'cve': 'CVE-2015-1286',
#   'cwe_list': ['CWE-79'],
#   'repo_name': 'chromium',
#   'commit_hash': '3b1351e5ead02ced4a026fcc6c6a24215a428f56',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/3b1351e5ead02ced4a026fcc6c6a24215a428f56',
#   'func': 'void V8ContextNativeHandler::GetModuleSystem(\n    const v8::FunctionCallbackInfo<v8::Value>& args) {\n  CHECK_EQ(args.Length(), 1);\n  CHECK(args[0]->IsObject());\n  v8::Local<v8::Context> v8_context =\n      v8::Local<v8::Object>::Cast(args[0])->CreationContext();\n  ScriptContext* context =\n      dispatcher_->script_context_set().GetByV8Context(v8_context);\n  args.GetReturnValue().Set(context->module_system()->NewInstance());\n}',
#   'graph_idx': 92669,
#   'vul': 1,
#   'id': 415},
#  {'cve': 'CVE-2014-3192',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'chromium',
#   'commit_hash': '04261ff0051f8495f81f166087dd4cfda045eaa0',
#   'git_url': 'https://github.com/chromium/chromium/commit/04261ff0051f8495f81f166087dd4cfda045eaa0',
#   'func': 'void ProcessingInstruction::setXSLStyleSheet(const String& href, const KURL& baseURL, const String& sheet)\n{\n    if (!inDocument()) {\n        ASSERT(!m_sheet);\n        return;\n    }\n\n    ASSERT(m_isXSL);\n    m_sheet = XSLStyleSheet::create(this, href, baseURL);\n    parseStyleSheet(sheet);\n}',
#   'graph_idx': 74844,
#   'vul': 1,
#   'id': 807},
#  {'cve': 'CVE-2020-13848',
#   'cwe_list': ['CWE-476'],
#   'repo_name': 'pupnp',
#   'commit_hash': 'c805c1de1141cb22f74c0d94dd5664bda37398e0',
#   'git_url': 'https://github.com/pupnp/pupnp/commit/c805c1de1141cb22f74c0d94dd5664bda37398e0',
#   'func': 'service_info *FindServiceControlURLPath(\n\tservice_table *table, const char *controlURLPath)\n{\n\tservice_info *finger = NULL;\n\turi_type parsed_url;\n\turi_type parsed_url_in;\n\n\tif (table && parse_uri(controlURLPath,\n\t\t\t     strlen(controlURLPath),\n\t\t\t     &parsed_url_in) == HTTP_SUCCESS) {\n\t\tfinger = table->serviceList;\n\t\twhile (finger) {\n\t\t\tif (finger->controlURL) {\n\t\t\t\tif (parse_uri(finger->controlURL,\n\t\t\t\t\t    strlen(finger->controlURL),\n\t\t\t\t\t    &parsed_url) == HTTP_SUCCESS) {\n\t\t\t\t\tif (!token_cmp(&parsed_url.pathquery,\n\t\t\t\t\t\t    &parsed_url_in.pathquery)) {\n\t\t\t\t\t\treturn finger;\n\t\t\t\t\t}\n\t\t\t\t}\n\t\t\t}\n\t\t\tfinger = finger->next;\n\t\t}\n\t}\n\n\treturn NULL;\n}',
#   'graph_idx': 293281,
#   'vul': 1,
#   'id': 892},
#  {'cve': 'CVE-2014-1439',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'facebook/hhvm',
#   'commit_hash': '95f96e7287effe2fcdfb9a5338d1a7e4f55b083b',
#   'git_url': 'https://github.com/facebook/hhvm/commit/95f96e7287effe2fcdfb9a5338d1a7e4f55b083b',
#   'func': 'virtual void requestInit() {\n    m_use_error = false;\n    m_errors.reset();\n    xmlParserInputBufferCreateFilenameDefault(nullptr);\n  }',
#   'graph_idx': 57667,
#   'vul': 1,
#   'id': 986},
#  {'cve': 'CVE-2021-3623',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'stefanberger/libtpms',
#   'commit_hash': '2e6173c',
#   'git_url': 'https://github.com/stefanberger/libtpms/commit/2e6173c',
#   'func': 'TPM_RC\nTPMI_YES_NO_Unmarshal(TPMI_YES_NO *target, BYTE **buffer, INT32 *size)\n{\n    TPM_RC rc = TPM_RC_SUCCESS;\n\n    if (rc == TPM_RC_SUCCESS) {\n\trc = UINT8_Unmarshal(target, buffer, size);  \n    }\n    if (rc == TPM_RC_SUCCESS) {\n\tswitch (*target) {\n\t  case NO:\n\t  case YES:\n\t    break;\n\t  default:\n\t    rc = TPM_RC_VALUE;\n\t}\n    }\n    return rc;\n}',
#   'graph_idx': 362844,
#   'vul': 1,
#   'id': 1152},
#  {'cve': 'CVE-2018-13006',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'gpac',
#   'commit_hash': 'bceb03fd2be95097a7b409ea59914f332fb6bc86',
#   'git_url': 'https://github.com/gpac/gpac/commit/bceb03fd2be95097a7b409ea59914f332fb6bc86',
#   'func': 'GF_Err hdlr_dump(GF_Box *a, FILE * trace)\n{\n\tGF_HandlerBox *p = (GF_HandlerBox *)a;\n\tgf_isom_box_dump_start(a, "HandlerBox", trace);\n\tif (p->nameUTF8 && (u32) p->nameUTF8[0] == strlen(p->nameUTF8+1)) {\n\t\tfprintf(trace, "hdlrType=\\"%s\\" Name=\\"%s\\" ", gf_4cc_to_str(p->handlerType), p->nameUTF8+1);\n\t} else {\n\t\tfprintf(trace, "hdlrType=\\"%s\\" Name=\\"%s\\" ", gf_4cc_to_str(p->handlerType), p->nameUTF8);\n\t}\n\tfprintf(trace, "reserved1=\\"%d\\" reserved2=\\"", p->reserved1);\n\tdump_data(trace, (char *) p->reserved2, 12);\n\tfprintf(trace, "\\"");\n\n\tfprintf(trace, ">\\n");\n\tgf_isom_box_dump_done("HandlerBox", a, trace);\n\treturn GF_OK;\n}',
#   'graph_idx': 223333,
#   'vul': 1,
#   'id': 1179},
#  {'cve': 'CVE-2013-6655',
#   'cwe_list': ['CWE-399'],
#   'repo_name': 'chromium',
#   'commit_hash': '5d37b543df5ddecfd6f1d89335f37f29dc86f80d',
#   'git_url': 'https://github.com/chromium/chromium/commit/5d37b543df5ddecfd6f1d89335f37f29dc86f80d',
#   'func': 'void FrameView::sendResizeEventIfNeeded()\n{\n    ASSERT(m_frame);\n\n    RenderView* renderView = this->renderView();\n    if (!renderView || renderView->document().printing())\n        return;\n\n    IntSize currentSize = layoutSize(IncludeScrollbars);\n    float currentZoomFactor = renderView->style()->zoom();\n\n    bool shouldSendResizeEvent = currentSize != m_lastViewportSize || currentZoomFactor != m_lastZoomFactor;\n\n    m_lastViewportSize = currentSize;\n    m_lastZoomFactor = currentZoomFactor;\n\n    if (!shouldSendResizeEvent)\n        return;\n\n    m_frame->eventHandler().sendResizeEvent();\n\n    if (isMainFrame())\n        InspectorInstrumentation::didResizeMainFrame(m_frame->page());\n}',
#   'graph_idx': 58625,
#   'vul': 1,
#   'id': 1236},
#  {'cve': 'CVE-2010-4526',
#   'cwe_list': ['CWE-362'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '50b5d6ad63821cea324a5a7a19854d4de1a0a819',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commitdiff;h=50b5d6ad63821cea324a5a7a19854d4de1a0a819',
#   'func': 'void sctp_icmp_proto_unreachable(struct sock *sk,\n\t\t\t   struct sctp_association *asoc,\n\t\t\t   struct sctp_transport *t)\n{\n\tSCTP_DEBUG_PRINTK("%s\\n",  __func__);\n\n\tsctp_do_sm(SCTP_EVENT_T_OTHER,\n\t\t   SCTP_ST_OTHER(SCTP_EVENT_ICMP_PROTO_UNREACH),\n\t\t   asoc->state, asoc->ep, asoc, t,\n\t\t   GFP_ATOMIC);\n\n}',
#   'graph_idx': 19069,
#   'vul': 1,
#   'id': 1435},
#  {'cve': 'CVE-2015-6756',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'pdfium',
#   'commit_hash': '396e872d872b760813036b7e7dd8bb68a8b61598',
#   'git_url': 'https://pdfium.googlesource.com/pdfium/+/396e872d872b760813036b7e7dd8bb68a8b61598',
#   'func': 'CPDFSDK_PageView::~CPDFSDK_PageView() {\n  CPDFDoc_Environment* pEnv = m_pSDKDoc->GetEnv();\n  int nAnnotCount = m_fxAnnotArray.GetSize();\n  for (int i = 0; i < nAnnotCount; i++) {\n    CPDFSDK_Annot* pAnnot = (CPDFSDK_Annot*)m_fxAnnotArray.GetAt(i);\n    // if there is a focused annot on the page, we should kill the focus first.\n    if (pAnnot == m_pSDKDoc->GetFocusAnnot())\n      KillFocusAnnot();\n    CPDFSDK_AnnotHandlerMgr* pAnnotHandlerMgr = pEnv->GetAnnotHandlerMgr();\n    ASSERT(pAnnotHandlerMgr);\n    pAnnotHandlerMgr->ReleaseAnnot(pAnnot);\n  }\n  m_fxAnnotArray.RemoveAll();\n\n  delete m_pAnnotList;\n  m_pAnnotList = NULL;\n}',
#   'graph_idx': 97668,
#   'vul': 1,
#   'id': 1464},
#  {'cve': 'CVE-2017-18218',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '27463ad99f738ed93c7c8b3e2e5bc8c4853a2ff2',
#   'git_url': 'https://github.com/torvalds/linux/commit/27463ad99f738ed93c7c8b3e2e5bc8c4853a2ff2',
#   'func': 'static netdev_tx_t hns_nic_net_xmit(struct sk_buff *skb,\n\t\t\t\t    struct net_device *ndev)\n{\n\tstruct hns_nic_priv *priv = netdev_priv(ndev);\n\tint ret;\n\n\tassert(skb->queue_mapping < ndev->ae_handle->q_num);\n\tret = hns_nic_net_xmit_hw(ndev, skb,\n\t\t\t\t  &tx_ring_data(priv, skb->queue_mapping));\n\tif (ret == NETDEV_TX_OK) {\n\t\tnetif_trans_update(ndev);\n\t\tndev->stats.tx_bytes += skb->len;\n\t\tndev->stats.tx_packets++;\n\t}\n\treturn (netdev_tx_t)ret;\n}',
#   'graph_idx': 212348,
#   'vul': 1,
#   'id': 1516},
#  {'cve': 'CVE-2020-15211',
#   'cwe_list': ['CWE-125', 'CWE-787'],
#   'repo_name': 'tensorflow',
#   'commit_hash': 'fff2c8326280c07733828f990548979bdc893859',
#   'git_url': 'https://github.com/tensorflow/tensorflow/commit/fff2c8326280c07733828f990548979bdc893859',
#   'func': 'TfLiteStatus Prepare(TfLiteContext* context, TfLiteNode* node) {\n  TFLITE_DCHECK(node->builtin_data != nullptr);\n  auto* params = reinterpret_cast<TfLitePoolParams*>(node->builtin_data);\n\n  TFLITE_DCHECK(node->user_data != nullptr);\n  OpData* data = static_cast<OpData*>(node->user_data);\n\n  const TfLiteTensor* input = GetInput(context, node, kInputTensor);\n  TfLiteTensor* output = GetOutput(context, node, kOutputTensor);\n\n  TF_LITE_ENSURE_STATUS(CalculateOpData(context, params, input, output, data));\n\n  if (input->type == kTfLiteFloat32) {\n    CalculateActivationRange(params->activation, &data->activation_min_f32,\n                             &data->activation_max_f32);\n  } else if (input->type == kTfLiteInt8 || input->type == kTfLiteUInt8) {\n    CalculateActivationRangeQuantized(context, params->activation, output,\n                                      &data->activation_min,\n                                      &data->activation_max);\n  }\n\n  return kTfLiteOk;\n}',
#   'graph_idx': 302806,
#   'vul': 1,
#   'id': 1537},
#  {'cve': 'CVE-2011-3209',
#   'cwe_list': ['CWE-189'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'f8bd2258e2d520dff28c855658bd24bdafb5102d',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=f8bd2258e2d520dff28c855658bd24bdafb5102d',
#   'func': 'static void sample_to_timespec(const clockid_t which_clock,\n\t\t\t       union cpu_time_count cpu,\n\t\t\t       struct timespec *tp)\n{\n\tif (CPUCLOCK_WHICH(which_clock) == CPUCLOCK_SCHED) {\n\t\ttp->tv_sec = div_long_long_rem(cpu.sched,\n\t\t\t\t\t       NSEC_PER_SEC, &tp->tv_nsec);\n\t} else {\n\t\tcputime_to_timespec(cpu.cpu, tp);\n\t}\n}',
#   'graph_idx': 35438,
#   'vul': 1,
#   'id': 1541},
#  {'cve': 'CVE-2020-22873',
#   'cwe_list': ['CWE-120'],
#   'repo_name': 'pcmacdon/jsish',
#   'commit_hash': '430ea27accd4d4ffddc946c9402e7c9064835a18',
#   'git_url': 'https://github.com/pcmacdon/jsish/commit/430ea27accd4d4ffddc946c9402e7c9064835a18',
#   'func': 'static Jsi_RC NumberToStringCmd(Jsi_Interp *interp, Jsi_Value *args, Jsi_Value *_this,\n    Jsi_Value **ret, Jsi_Func *funcPtr)\n{\n    char buf[500];\n    int radix = 10, skip = 0, argc = Jsi_ValueGetLength(interp, args);\n    Jsi_Number num;\n    Jsi_Value *v;\n    ChkStringN(_this, funcPtr, v);\n    Jsi_GetDoubleFromValue(interp, v, &num);\n    if (argc>skip && (Jsi_GetIntFromValue(interp, Jsi_ValueArrayIndex(interp, args, skip), &radix) != JSI_OK\n        || radix<2))\n        return JSI_ERROR;\n    if (argc==skip)\n        return jsi_ObjectToStringCmd(interp, args, _this, ret, funcPtr);\n    switch (radix) {\n        case 16: snprintf(buf, sizeof(buf), "%" PRIx64, (Jsi_Wide)num); break;\n        case 8: snprintf(buf, sizeof(buf), "%" PRIo64, (Jsi_Wide)num); break;\n        case 10: snprintf(buf, sizeof(buf), "%" PRId64, (Jsi_Wide)num); break;\n        default: return jsi_ObjectToStringCmd(interp, args, _this, ret, funcPtr);\n    }\n    Jsi_ValueMakeStringDup(interp, ret, buf);\n    return JSI_OK;\n}',
#   'graph_idx': 329660,
#   'vul': 1,
#   'id': 1642},
#  {'cve': 'CVE-2016-6871',
#   'cwe_list': ['CWE-190'],
#   'repo_name': 'facebook/hhvm',
#   'commit_hash': 'c00fc9d3003eb06226b58b6a48555f1456ee2475',
#   'git_url': 'https://github.com/facebook/hhvm/commit/c00fc9d3003eb06226b58b6a48555f1456ee2475',
#   'func': 'static String HHVM_FUNCTION(bcsub, const String& left, const String& right,\n                            int64_t scale /* = -1 */) {\n  if (scale < 0) scale = BCG(bc_precision);\n  bc_num first, second, result;\n  bc_init_num(&first);\n  bc_init_num(&second);\n  bc_init_num(&result);\n  php_str2num(&first, (char*)left.data());\n  php_str2num(&second, (char*)right.data());\n  bc_sub(first, second, &result, scale);\n  if (result->n_scale > scale) {\n    result->n_scale = scale;\n  }\n  String ret(bc_num2str(result), AttachString);\n  bc_free_num(&first);\n  bc_free_num(&second);\n  bc_free_num(&result);\n  return ret;\n}',
#   'graph_idx': 161273,
#   'vul': 1,
#   'id': 1887},
#  {'cve': 'CVE-2017-12146',
#   'cwe_list': ['CWE-362'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '6265539776a0810b7ce6398c27866ddb9c6bd154',
#   'git_url': 'https://github.com/torvalds/linux/commit/6265539776a0810b7ce6398c27866ddb9c6bd154',
#   'func': 'static ssize_t driver_override_show(struct device *dev,\n\t\t\t\t    struct device_attribute *attr, char *buf)\n{\n\tstruct platform_device *pdev = to_platform_device(dev);\n\n\treturn sprintf(buf, "%s\\n", pdev->driver_override);\n}',
#   'graph_idx': 192256,
#   'vul': 1,
#   'id': 2026},
#  {'cve': 'CVE-2014-1896',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '2efcb0193bf3916c8ce34882e845f5ceb1e511f7',
#   'git_url': 'https://github.com/xen-project/xen/commit/2efcb0193bf3916c8ce34882e845f5ceb1e511f7',
#   'func': 'static inline int fast_get_data_ready(struct libxenvchan *ctrl, size_t request)\n{\n\tint ready = rd_prod(ctrl) - rd_cons(ctrl);\n\tif (ready >= request)\n\t\treturn ready;\n\t/* We plan to consume all data; please tell us if you send more */\n\trequest_notify(ctrl, VCHAN_NOTIFY_WRITE);\n\t/*\n\t * If the writer moved rd_prod after our read but before request, we\n\t * will not get notified even though the actual amount of data ready is\n\t * above request. Reread rd_prod to cover this case.\n\t */\n\treturn rd_prod(ctrl) - rd_cons(ctrl);\n}',
#   'graph_idx': 64371,
#   'vul': 1,
#   'id': 2222},
#  {'cve': 'CVE-2022-25298',
#   'cwe_list': ['CWE-22'],
#   'repo_name': 'sprinfall/webcc',
#   'commit_hash': '55a45fd5039061d5cc62e9f1b9d1f7e97a15143f',
#   'git_url': 'https://github.com/sprinfall/webcc/commit/55a45fd5039061d5cc62e9f1b9d1f7e97a15143f',
#   'func': 'ResponsePtr Server::ServeStatic(RequestPtr request) {\n  assert(request->method() == methods::kGet);\n\n  if (doc_root_.empty()) {\n    LOG_INFO("The doc root was not specified");\n    return {};\n  }\n\n  fs::path path = doc_root_ / request->url().path();\n\n  try {\n    // NOTE: FileBody might throw Error::kFileError.\n    auto body = std::make_shared<FileBody>(path, file_chunk_size_);\n\n    auto response = std::make_shared<Response>(Status::kOK);\n\n    std::string extension = path.extension().string();\n    response->SetContentType(media_types::FromExtension(extension), "");\n\n    // NOTE: Gzip compression is not supported.\n    response->SetBody(body, true);\n\n    return response;\n\n  } catch (const Error& error) {\n    LOG_ERRO("File error: %s", error.message().c_str());\n    return {};\n  }\n}',
#   'graph_idx': 359097,
#   'vul': 1,
#   'id': 2317},
#  {'cve': 'CVE-2012-2321',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'a5f540db7354b76bcabd0a05d8eb8ba2bff4e911',
#   'git_url': 'http://git.kernel.org/?p=network/connman/connman.git;a=commit;h=a5f540db7354b76bcabd0a05d8eb8ba2bff4e911',
#   'func': 'static int loopback_set_hostname(const char *hostname)\n{\n\tint err;\n\n\tif (g_strcmp0(hostname, "<hostname>") == 0)\n\t\treturn 0;\n\n\tif (sethostname(hostname, strlen(hostname)) < 0) {\n\t\terr = -errno;\n\t\tconnman_error("Failed to set hostname to %s", hostname);\n\t\treturn err;\n\t}\n\n\tconnman_info("Setting hostname to %s", hostname);\n\n\treturn 0;\n}',
#   'graph_idx': 28063,
#   'vul': 1,
#   'id': 2457},
#  {'cve': 'CVE-2014-7920',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'android',
#   'commit_hash': '36d15776c37a6512d452628673e6286f8d9cf89c',
#   'git_url': 'https://android.googlesource.com/platform/frameworks/av/+/36d1577',
#   'func': 'status_t AudioPolicyService::stopOutput(audio_io_handle_t output,\n                                        audio_stream_type_t stream,\n                                        int session)\n{\n    if (mAudioPolicyManager == NULL) {\n        return NO_INIT;\n    }\n    ALOGV("stopOutput()");\n    mOutputCommandThread->stopOutputCommand(output, stream, session);\n    return NO_ERROR;\n}',
#   'graph_idx': 173981,
#   'vul': 1,
#   'id': 2465},
#  {'cve': 'CVE-2016-1662',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '34c97b31e61e8329e19188b46a489412a16d2b63',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/34c97b31e61e8329e19188b46a489412a16d2b63',
#   'func': 'void GCCallback::RunCallback() {\n  v8::Isolate* isolate = context_->isolate();\n  v8::HandleScope handle_scope(isolate);\n  context_->CallFunction(v8::Local<v8::Function>::New(isolate, callback_));\n  delete this;\n}',
#   'graph_idx': 118262,
#   'vul': 1,
#   'id': 2578},
#  {'cve': 'CVE-2015-6767',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '4b5eefe562bd45c059f5dd93079450db5610788a',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/4b5eefe562bd45c059f5dd93079450db5610788a',
#   'func': 'void AppCacheDispatcherHost::OnChannelConnected(int32 peer_pid) {\n  if (appcache_service_.get()) {\n    backend_impl_.Initialize(\n        appcache_service_.get(), &frontend_proxy_, process_id_);\n    get_status_callback_ =\n        base::Bind(&AppCacheDispatcherHost::GetStatusCallback,\n                   base::Unretained(this));\n    start_update_callback_ =\n        base::Bind(&AppCacheDispatcherHost::StartUpdateCallback,\n                   base::Unretained(this));\n    swap_cache_callback_ =\n        base::Bind(&AppCacheDispatcherHost::SwapCacheCallback,\n                   base::Unretained(this));\n  }\n}',
#   'graph_idx': 101079,
#   'vul': 1,
#   'id': 2630},
#  {'cve': 'CVE-2009-5155',
#   'cwe_list': ['CWE-19'],
#   'repo_name': 'glibc',
#   'commit_hash': 'eb04c21373e2a2885f3d52ff192b0499afe3c672',
#   'git_url': 'https://sourceware.org/git/gitweb.cgi?p=glibc.git;h=eb04c21373e2a2885f3d52ff192b0499afe3c672',
#   'func': 'static void __attribute__ ((unused))\nbitset_not (bitset_t set)\n{\n  int bitset_i;\n  for (bitset_i = 0; bitset_i < BITSET_WORDS; ++bitset_i)\n    set[bitset_i] = ~set[bitset_i];\n}',
#   'graph_idx': 246100,
#   'vul': 1,
#   'id': 2800},
#  {'cve': 'CVE-2018-21017',
#   'cwe_list': ['CWE-401'],
#   'repo_name': 'gpac',
#   'commit_hash': 'd2371b4b204f0a3c0af51ad4e9b491144dd1225c',
#   'git_url': 'https://github.com/gpac/gpac/commit/d2371b4b204f0a3c0af51ad4e9b491144dd1225c',
#   'func': 'GF_Err dinf_Read(GF_Box *s, GF_BitStream *bs)\n{\n\tGF_Err e = gf_isom_box_array_read(s, bs, dinf_AddBox);\n\tif (e) {\n\t\treturn e;\n\t}\n\tif (!((GF_DataInformationBox *)s)->dref) {\n\t\tGF_LOG(GF_LOG_ERROR, GF_LOG_CONTAINER, ("[iso file] Missing dref box in dinf\\n"));\n\t\t((GF_DataInformationBox *)s)->dref = (GF_DataReferenceBox *)gf_isom_box_new(GF_ISOM_BOX_TYPE_DREF);\n\t}\n\treturn GF_OK;\n}',
#   'graph_idx': 263107,
#   'vul': 1,
#   'id': 2805},
#  {'cve': 'CVE-2014-1710',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'chromium',
#   'commit_hash': '5bf02fe48f23634b215a40d584891f787fc825b0',
#   'git_url': 'https://github.com/chromium/chromium/commit/5bf02fe48f23634b215a40d584891f787fc825b0',
#   'func': 'void ClearSharedMemory() {\n      memset(data_.get(), kInitialMemoryValue, kSharedBufferSize);\n    }',
#   'graph_idx': 61544,
#   'vul': 1,
#   'id': 2926},
#  {'cve': 'CVE-2011-2479',
#   'cwe_list': ['CWE-399'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '78f11a255749d09025f54d4e2df4fbcb031530e2',
#   'git_url': 'https://github.com/torvalds/linux/commit/78f11a255749d09025f54d4e2df4fbcb031530e2',
#   'func': 'static inline void vma_adjust_trans_huge(struct vm_area_struct *vma,\n\t\t\t\t\t unsigned long start,\n\t\t\t\t\t unsigned long end,\n\t\t\t\t\t long adjust_next)\n{\n\tif (!vma->anon_vma || vma->vm_ops || vma->vm_file)\n\t\treturn;\n\t__vma_adjust_trans_huge(vma, start, end, adjust_next);\n}',
#   'graph_idx': 39274,
#   'vul': 1,
#   'id': 2954},
#  {'cve': 'CVE-2009-4035',
#   'cwe_list': ['CWE-94'],
#   'repo_name': 'poppler',
#   'commit_hash': '4b4fc5c017bf147c9069bbce32fc14467bd2a81a',
#   'git_url': 'http://cgit.freedesktop.org/poppler/poppler/commit/fofi/FoFiType1.cc?id=4b4fc5c0',
#   'func': "char *FoFiType1C::getString(int sid, char *buf, GBool *ok) {\n  Type1CIndexVal val;\n  int n;\n\n  if (sid < 391) {\n    strcpy(buf, fofiType1CStdStrings[sid]);\n  } else {\n    sid -= 391;\n    getIndexVal(&stringIdx, sid, &val, ok);\n    if (ok) {\n      if ((n = val.len) > 255) {\n\tn = 255;\n      }\n      strncpy(buf, (char *)&file[val.pos], n);\n      buf[n] = '\\0';\n    } else {\n      buf[0] = '\\0';\n    }\n  }\n  return buf;\n}",
#   'graph_idx': 10223,
#   'vul': 1,
#   'id': 3045},
#  {'cve': 'CVE-2020-36557',
#   'cwe_list': ['CWE-416', 'CWE-362'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ca4463bf8438b403596edd0ec961ca0d4fbe0220',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=ca4463bf8438b403596edd0ec961ca0d4fbe0220',
#   'func': 'static void vt_disallocate_all(void)\n{\n\tstruct vc_data *vc[MAX_NR_CONSOLES];\n\tint i;\n\n\tconsole_lock();\n\tfor (i = 1; i < MAX_NR_CONSOLES; i++)\n\t\tif (!vt_busy(i))\n\t\t\tvc[i] = vc_deallocate(i);\n\t\telse\n\t\t\tvc[i] = NULL;\n\tconsole_unlock();\n\n\tfor (i = 1; i < MAX_NR_CONSOLES; i++) {\n\t\tif (vc[i] && i >= MIN_NR_CONSOLES) {\n\t\t\ttty_port_destroy(&vc[i]->port);\n\t\t\tkfree(vc[i]);\n\t\t}\n\t}\n}',
#   'graph_idx': 386043,
#   'vul': 1,
#   'id': 3100},
#  {'cve': 'CVE-2016-1690',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '7e112c1563632f57cfa1c4fa964987f823da17fa',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/7e112c1563632f57cfa1c4fa964987f823da17fa',
#   'func': 'bool PasswordGenerationAgent::ShouldAnalyzeDocument() const {\n  // Make sure that this security origin is allowed to use password manager.\n  // Generating a password that can\'t be saved is a bad idea.\n  blink::WebSecurityOrigin origin =\n      render_frame()->GetWebFrame()->document().getSecurityOrigin();\n  if (!origin.canAccessPasswordManager()) {\n    VLOG(1) << "No PasswordManager access";\n    return false;\n  }\n\n  return true;\n}',
#   'graph_idx': 122166,
#   'vul': 1,
#   'id': 3463},
#  {'cve': 'CVE-2013-2920',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'chromium',
#   'commit_hash': '3ca8e38ff57e83fcce76f9b54cd8f8bfa09c34ad',
#   'git_url': 'https://github.com/chromium/chromium/commit/3ca8e38ff57e83fcce76f9b54cd8f8bfa09c34ad',
#   'func': 'bool DoResolveRelativeHost(const char* base_url,\n                           const url_parse::Parsed& base_parsed,\n                           const CHAR* relative_url,\n                           const url_parse::Component& relative_component,\n                           CharsetConverter* query_converter,\n                           CanonOutput* output,\n                           url_parse::Parsed* out_parsed) {\n  // Parse the relative URL, just like we would for anything following a\n  // scheme.\n  url_parse::Parsed relative_parsed;  // Everything but the scheme is valid.\n  url_parse::ParseAfterScheme(&relative_url[relative_component.begin],\n                              relative_component.len, relative_component.begin,\n                              &relative_parsed);\n\n  // Now we can just use the replacement function to replace all the necessary\n  // parts of the old URL with the new one.\n  Replacements<CHAR> replacements;\n  replacements.SetUsername(relative_url, relative_parsed.username);\n  replacements.SetPassword(relative_url, relative_parsed.password);\n  replacements.SetHost(relative_url, relative_parsed.host);\n  replacements.SetPort(relative_url, relative_parsed.port);\n  replacements.SetPath(relative_url, relative_parsed.path);\n  replacements.SetQuery(relative_url, relative_parsed.query);\n  replacements.SetRef(relative_url, relative_parsed.ref);\n\n  return ReplaceStandardURL(base_url, base_parsed, replacements,\n                            query_converter, output, out_parsed);\n}',
#   'graph_idx': 49807,
#   'vul': 1,
#   'id': 3545},
#  {'cve': 'CVE-2012-1179',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '4a1d704194a441bf83c636004a479e01360ec850',
#   'git_url': 'https://github.com/torvalds/linux/commit/4a1d704194a441bf83c636004a479e01360ec850',
#   'func': 'static int mem_cgroup_count_precharge_pte_range(pmd_t *pmd,\n\t\t\t\t\tunsigned long addr, unsigned long end,\n\t\t\t\t\tstruct mm_walk *walk)\n{\n\tstruct vm_area_struct *vma = walk->private;\n\tpte_t *pte;\n\tspinlock_t *ptl;\n\n\tsplit_huge_page_pmd(walk->mm, pmd);\n\n\tpte = pte_offset_map_lock(vma->vm_mm, pmd, addr, &ptl);\n\tfor (; addr != end; pte++, addr += PAGE_SIZE)\n\t\tif (is_target_pte_for_mc(vma, addr, *pte, NULL))\n\t\t\tmc.precharge++;\t/* increment precharge temporarily */\n\tpte_unmap_unlock(pte - 1, ptl);\n\tcond_resched();\n\n\treturn 0;\n}',
#   'graph_idx': 26921,
#   'vul': 1,
#   'id': 3605},
#  {'cve': 'CVE-2016-10905',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '36e4ad0316c017d5b271378ed9a1c9a4b77fab5f',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=36e4ad0316c017d5b271378ed9a1c9a4b77fab5f',
#   'func': 'void gfs2_clear_rgrpd(struct gfs2_sbd *sdp)\n{\n\tstruct rb_node *n;\n\tstruct gfs2_rgrpd *rgd;\n\tstruct gfs2_glock *gl;\n\n\twhile ((n = rb_first(&sdp->sd_rindex_tree))) {\n\t\trgd = rb_entry(n, struct gfs2_rgrpd, rd_node);\n\t\tgl = rgd->rd_gl;\n\n\t\trb_erase(n, &sdp->sd_rindex_tree);\n\n\t\tif (gl) {\n\t\t\tspin_lock(&gl->gl_lockref.lock);\n\t\t\tgl->gl_object = NULL;\n\t\t\tspin_unlock(&gl->gl_lockref.lock);\n\t\t\tgfs2_glock_add_to_lru(gl);\n\t\t\tgfs2_glock_put(gl);\n\t\t}\n\n\t\tgfs2_free_clones(rgd);\n\t\tkfree(rgd->rd_bits);\n\t\treturn_all_reservations(rgd);\n\t\tkmem_cache_free(gfs2_rgrpd_cachep, rgd);\n\t}\n}',
#   'graph_idx': 258762,
#   'vul': 1,
#   'id': 3624},
#  {'cve': 'CVE-2023-25136',
#   'cwe_list': ['CWE-415'],
#   'repo_name': 'openssh/openssh-portable',
#   'commit_hash': '486c4dc3b83b4b67d663fb0fa62bc24138ec3946',
#   'git_url': 'https://github.com/openssh/openssh-portable/commit/486c4dc3b83b4b67d663fb0fa62bc24138ec3946',
#   'func': 'char *\ncompat_kex_proposal(struct ssh *ssh, char *p)\n{\n\tif ((ssh->compat & (SSH_BUG_CURVE25519PAD|SSH_OLD_DHGEX)) == 0)\n\t\treturn p;\n\tdebug2_f("original KEX proposal: %s", p);\n\tif ((ssh->compat & SSH_BUG_CURVE25519PAD) != 0)\n\t\tif ((p = match_filter_denylist(p,\n\t\t    "curve25519-sha256@libssh.org")) == NULL)\n\t\t\tfatal("match_filter_denylist failed");\n\tif ((ssh->compat & SSH_OLD_DHGEX) != 0) {\n\t\tif ((p = match_filter_denylist(p,\n\t\t    "diffie-hellman-group-exchange-sha256,"\n\t\t    "diffie-hellman-group-exchange-sha1")) == NULL)\n\t\t\tfatal("match_filter_denylist failed");\n\t}\n\tdebug2_f("compat KEX proposal: %s", p);\n\tif (*p == \'\\0\')\n\t\tfatal("No supported key exchange algorithms found");\n\treturn p;\n}',
#   'graph_idx': 422568,
#   'vul': 1,
#   'id': 3663},
#  {'cve': 'CVE-2015-4177',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'cd4a40174b71acd021877341684d8bb1dc8ea4ae',
#   'git_url': 'http://git.kernel.org/cgit/linux/kernel/git/torvalds/linux.git/commit/?id=cd4a40174b71acd021877341684d8bb1dc8ea4ae',
#   'func': 'struct vfsmount *collect_mounts(struct path *path)\n{\n\tstruct mount *tree;\n\tnamespace_lock();\n\ttree = copy_tree(real_mount(path->mnt), path->dentry,\n\t\t\t CL_COPY_ALL | CL_PRIVATE);\n\tnamespace_unlock();\n\tif (IS_ERR(tree))\n\t\treturn ERR_CAST(tree);\n\treturn &tree->mnt;\n}',
#   'graph_idx': 116119,
#   'vul': 1,
#   'id': 3793},
#  {'cve': 'CVE-2014-8559',
#   'cwe_list': ['CWE-400'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '946e51f2bf37f1656916eb75bd0742ba33983c28',
#   'git_url': 'https://git.kernel.org/cgit/linux/kernel/git/torvalds/linux.git/commit/?id=946e51f2bf37f1656916eb75bd0742ba33983c28',
#   'func': 'void lustre_dump_dentry(struct dentry *dentry, int recur)\n{\n\tstruct list_head *tmp;\n\tint subdirs = 0;\n\n\tLASSERT(dentry != NULL);\n\n\tlist_for_each(tmp, &dentry->d_subdirs)\n\t\tsubdirs++;\n\n\tCERROR("dentry %p dump: name=%.*s parent=%.*s (%p), inode=%p, count=%u,"\n\t       " flags=0x%x, fsdata=%p, %d subdirs\\n", dentry,\n\t       dentry->d_name.len, dentry->d_name.name,\n\t       dentry->d_parent->d_name.len, dentry->d_parent->d_name.name,\n\t       dentry->d_parent, dentry->d_inode, d_count(dentry),\n\t       dentry->d_flags, dentry->d_fsdata, subdirs);\n\tif (dentry->d_inode != NULL)\n\t\tll_dump_inode(dentry->d_inode);\n\n\tif (recur == 0)\n\t\treturn;\n\n\tlist_for_each(tmp, &dentry->d_subdirs) {\n\t\tstruct dentry *d = list_entry(tmp, struct dentry, d_u.d_child);\n\t\tlustre_dump_dentry(d, recur - 1);\n\t}\n}',
#   'graph_idx': 78397,
#   'vul': 1,
#   'id': 3854},
#  {'cve': 'CVE-2017-9766',
#   'cwe_list': ['CWE-674'],
#   'repo_name': 'wireshark',
#   'commit_hash': 'd6e888400ba64de3147d1111a4c23edf389b0000',
#   'git_url': 'https://github.com/wireshark/wireshark/commit/d6e888400ba64de3147d1111a4c23edf389b0000',
#   'func': 'static int\ndissect_IPNIO_Write_rqst(tvbuff_t *tvb, int offset,\n    packet_info *pinfo, proto_tree *tree, dcerpc_info *di, guint8 *drep)\n{\n    pnio_ar_t *ar = NULL;\n\n    offset = dissect_IPNIO_rqst_header(tvb, offset, pinfo, tree, di, drep);\n\n    offset = dissect_IODWriteReq(tvb, offset, pinfo, tree, drep, &ar);\n\n    if (ar != NULL) {\n        pnio_ar_info(tvb, pinfo, tree, ar);\n    }\n\n    return offset;\n}',
#   'graph_idx': 182425,
#   'vul': 1,
#   'id': 3883},
#  {'cve': 'CVE-2014-7924',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '2d74497dfa5e6fd6ddddc93248c322a57dd8dd2c',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/2d74497dfa5e6fd6ddddc93248c322a57dd8dd2c',
#   'func': 'void IndexedDBDispatcherHost::OnAckReceivedBlobs(\n    const std::vector<std::string>& uuids) {\n  DCHECK(indexed_db_context_->TaskRunner()->RunsTasksOnCurrentThread());\n  for (const auto& uuid : uuids)\n    DropBlobDataHandle(uuid);\n}',
#   'graph_idx': 82465,
#   'vul': 1,
#   'id': 3982},
#  {'cve': 'CVE-2016-0824',
#   'cwe_list': ['CWE-254', 'CWE-200'],
#   'repo_name': 'android',
#   'commit_hash': 'ffab15eb80630dc799eb410855c93525b75233c3',
#   'git_url': 'https://android.googlesource.com/platform/external/libmpeg2/+/ffab15eb80630dc799eb410855c93525b75233c3',
#   'func': 'UWORD16 impeg2d_get_mb_addr_incr(stream_t *ps_stream)\n{\n    UWORD16 u2_mb_addr_incr = 0;\n    while (impeg2d_bit_stream_nxt(ps_stream,MB_ESCAPE_CODE_LEN) == MB_ESCAPE_CODE)\n    {\n        impeg2d_bit_stream_flush(ps_stream,MB_ESCAPE_CODE_LEN);\n        u2_mb_addr_incr += 33;\n    }\n    u2_mb_addr_incr += impeg2d_dec_vld_symbol(ps_stream,gai2_impeg2d_mb_addr_incr,MB_ADDR_INCR_LEN) +\n        MB_ADDR_INCR_OFFSET;\n    return(u2_mb_addr_incr);\n}',
#   'graph_idx': 109671,
#   'vul': 1,
#   'id': 3999},
#  {'cve': 'CVE-2021-3623',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'stefanberger/libtpms',
#   'commit_hash': '2e6173c',
#   'git_url': 'https://github.com/stefanberger/libtpms/commit/2e6173c',
#   'func': 'TPM_RC\nTPMI_RH_HIERARCHY_AUTH_Unmarshal(TPMI_RH_HIERARCHY_AUTH *target, BYTE **buffer, INT32 *size)\n{\n    TPM_RC rc = TPM_RC_SUCCESS;\n    \n    if (rc == TPM_RC_SUCCESS) {\n\trc = TPM_HANDLE_Unmarshal(target, buffer, size);  \n    }\n    if (rc == TPM_RC_SUCCESS) {\n\tswitch (*target) {\n\t  case TPM_RH_OWNER:\n\t  case TPM_RH_PLATFORM:\n\t  case TPM_RH_ENDORSEMENT:\n\t  case TPM_RH_LOCKOUT:\n\t    break;\n\t  default:\n\t    rc = TPM_RC_VALUE;\n\t}\n    }\n    return rc;\n}',
#   'graph_idx': 362878,
#   'vul': 1,
#   'id': 4097},
#  {'cve': 'CVE-2022-2318',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '9cc02ede696272c5271a401e4f27c262359bc2f6',
#   'git_url': 'https://github.com/torvalds/linux/commit/9cc02ede696272c5271a401e4f27c262359bc2f6',
#   'func': 'void rose_start_heartbeat(struct sock *sk)\n{\n\tdel_timer(&sk->sk_timer);\n\n\tsk->sk_timer.function = rose_heartbeat_expiry;\n\tsk->sk_timer.expires  = jiffies + 5 * HZ;\n\n\tadd_timer(&sk->sk_timer);\n}',
#   'graph_idx': 384965,
#   'vul': 1,
#   'id': 4123},
#  {'cve': 'CVE-2020-8944',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'google/asylo',
#   'commit_hash': '382da2b8b09cbf928668a2445efb778f76bd9c8a',
#   'git_url': 'https://github.com/google/asylo/commit/382da2b8b09cbf928668a2445efb778f76bd9c8a',
#   'func': 'int ecall_restore(const char *input, uint64_t input_len, char **output,\n                  uint64_t *output_len) {\n  if (!asylo::primitives::TrustedPrimitives::IsOutsideEnclave(input,\n                                                              input_len) ||\n      !asylo::primitives::TrustedPrimitives::IsOutsideEnclave(\n          output_len, sizeof(uint64_t))) {\n    asylo::primitives::TrustedPrimitives::BestEffortAbort(\n        "ecall_restore: input/output found to not be in untrusted memory.");\n  }\n  int result = 0;\n  size_t tmp_output_len;\n  try {\n    result = asylo::Restore(input, static_cast<size_t>(input_len), output,\n                            &tmp_output_len);\n  } catch (...) {\n    LOG(FATAL) << "Uncaught exception in enclave";\n  }\n\n  if (output_len) {\n    *output_len = static_cast<uint64_t>(tmp_output_len);\n  }\n  return result;\n}',
#   'graph_idx': 309602,
#   'vul': 1,
#   'id': 4134},
#  {'cve': 'CVE-2010-4818',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'xorg/xserver',
#   'commit_hash': '6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'git_url': 'http://cgit.freedesktop.org/xorg/xserver/commit?id=6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'func': 'int __glXDispSwap_ClientInfo(__GLXclientState *cl, GLbyte *pc)\n{\n    xGLXClientInfoReq *req = (xGLXClientInfoReq *)pc;\n    __GLX_DECLARE_SWAP_VARIABLES;\n\n    __GLX_SWAP_SHORT(&req->length);\n    __GLX_SWAP_INT(&req->major);\n    __GLX_SWAP_INT(&req->minor);\n    __GLX_SWAP_INT(&req->numbytes);\n\n    return __glXDisp_ClientInfo(cl, pc);\n}',
#   'graph_idx': 34494,
#   'vul': 1,
#   'id': 4138},
#  {'cve': 'CVE-2019-12379',
#   'cwe_list': ['CWE-401'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '84ecc2f6eb1cb12e6d44818f94fa49b50f06e6ac',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/gregkh/tty.git/commit/?h=tty-next&id=84ecc2f6eb1cb12e6d44818f94fa49b50f06e6ac',
#   'func': 'static int\ncon_insert_unipair(struct uni_pagedir *p, u_short unicode, u_short fontpos)\n{\n\tint i, n;\n\tu16 **p1, *p2;\n\n\tp1 = p->uni_pgdir[n = unicode >> 11];\n\tif (!p1) {\n\t\tp1 = p->uni_pgdir[n] = kmalloc_array(32, sizeof(u16 *),\n\t\t\t\t\t\t     GFP_KERNEL);\n\t\tif (!p1) return -ENOMEM;\n\t\tfor (i = 0; i < 32; i++)\n\t\t\tp1[i] = NULL;\n\t}\n\n\tp2 = p1[n = (unicode >> 6) & 0x1f];\n\tif (!p2) {\n\t\tp2 = p1[n] = kmalloc_array(64, sizeof(u16), GFP_KERNEL);\n\t\tif (!p2) return -ENOMEM;\n\t\tmemset(p2, 0xff, 64*sizeof(u16)); /* No glyphs for the characters (yet) */\n\t}\n\n\tp2[unicode & 0x3f] = fontpos;\n\t\n\tp->sum += (fontpos << 20) + unicode;\n\n\treturn 0;\n}',
#   'graph_idx': 252375,
#   'vul': 1,
#   'id': 4400},
#  {'cve': 'CVE-2015-1253',
#   'cwe_list': ['CWE-284'],
#   'repo_name': 'chromium',
#   'commit_hash': 'ad6d56fe76a49244896156182c30d8e9ff3afbf2',
#   'git_url': 'https://github.com/chromium/chromium/commit/ad6d56fe76a49244896156182c30d8e9ff3afbf2',
#   'func': 'static inline void insert(HTMLConstructionSiteTask& task)\n{\n    if (isHTMLTemplateElement(*task.parent))\n        task.parent = toHTMLTemplateElement(task.parent.get())->content();\n\n    if (ContainerNode* parent = task.child->parentNode())\n        parent->parserRemoveChild(*task.child);\n\n    if (task.nextChild)\n        task.parent->parserInsertBefore(task.child.get(), *task.nextChild);\n    else\n        task.parent->parserAppendChild(task.child.get());\n}',
#   'graph_idx': 89119,
#   'vul': 1,
#   'id': 4402},
#  {'cve': 'CVE-2021-20317',
#   'cwe_list': ['CWE-665'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '511885d7061eda3eb1faf3f57dcc936ff75863f1',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/tip/tip.git/commit/?id=511885d7061eda3eb1faf3f57dcc936ff75863f1',
#   'func': 'static inline\nstruct timerqueue_node *timerqueue_getnext(struct timerqueue_head *head)\n{\n\treturn head->next;\n}',
#   'graph_idx': 341138,
#   'vul': 1,
#   'id': 4683},
#  {'cve': 'CVE-2014-3479',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'file',
#   'commit_hash': '36fadd29849b8087af9f4586f89dbf74ea45be67',
#   'git_url': 'https://github.com/file/file/commit/36fadd29849b8087af9f4586f89dbf74ea45be67',
#   'func': 'static int\ncdf_check_stream_offset(const cdf_stream_t *sst, const cdf_header_t *h,\n    const void *p, size_t tail, int line)\n{\n\tconst char *b = (const char *)sst->sst_tab;\n\tconst char *e = ((const char *)p) + tail;\n\t(void)&line;\n\tif (e >= b && (size_t)(e - b) <= CDF_SEC_SIZE(h) * sst->sst_len)\n\t\treturn 0;\n\tDPRINTF(("%d: offset begin %p < end %p || %" SIZE_T_FORMAT "u"\n\t    " > %" SIZE_T_FORMAT "u [%" SIZE_T_FORMAT "u %"\n\t    SIZE_T_FORMAT "u]\\n", line, b, e, (size_t)(e - b),\n\t    CDF_SEC_SIZE(h) * sst->sst_len, CDF_SEC_SIZE(h), sst->sst_len));\n\terrno = EFTYPE;\n\treturn -1;\n}',
#   'graph_idx': 69499,
#   'vul': 1,
#   'id': 4735},
#  {'cve': 'CVE-2022-1671',
#   'cwe_list': ['CWE-476'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ff8376ade4f668130385839cef586a0990f8ef87',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=ff8376ade4f668130385839cef586a0990f8ef87',
#   'func': 'static void rxrpc_free_preparse_s(struct key_preparsed_payload *prep)\n{\n\tconst struct rxrpc_security *sec = prep->payload.data[1];\n\n\tif (sec)\n\t\tsec->free_preparse_server_key(prep);\n}',
#   'graph_idx': 386478,
#   'vul': 1,
#   'id': 4800},
#  {'cve': 'CVE-2009-2691',
#   'cwe_list': ['CWE-200'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '00f89d218523b9bf6b522349c039d5ac80aa536d',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=00f89d218523b9bf6b522349c039d5ac80aa536d',
#   'func': 'struct mm_struct *mm_for_maps(struct task_struct *task)\n{\n\tstruct mm_struct *mm = get_task_mm(task);\n\tif (!mm)\n\t\treturn NULL;\n\tif (mm != current->mm) {\n\t\t/*\n\t\t * task->mm can be changed before security check,\n\t\t * in that case we must notice the change after.\n\t\t */\n\t\tif (!ptrace_may_access(task, PTRACE_MODE_READ) ||\n\t\t    mm != task->mm) {\n\t\t\tmmput(mm);\n\t\t\treturn NULL;\n\t\t}\n\t}\n\tdown_read(&mm->mmap_sem);\n\treturn mm;\n}',
#   'graph_idx': 4618,
#   'vul': 1,
#   'id': 4886},
#  {'cve': 'CVE-2010-0008',
#   'cwe_list': ['CWE-399'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ece25dfa0991f65c4e1d26beb1c3c45bda4239b8',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=ece25dfa0991f65c4e1d26beb1c3c45bda4239b8',
#   'func': 'sctp_disposition_t sctp_sf_discard_chunk(const struct sctp_endpoint *ep,\n\t\t\t\t\t const struct sctp_association *asoc,\n\t\t\t\t\t const sctp_subtype_t type,\n\t\t\t\t\t void *arg,\n\t\t\t\t\t sctp_cmd_seq_t *commands)\n{\n\tSCTP_DEBUG_PRINTK("Chunk %d is discarded\\n", type.chunk);\n\treturn SCTP_DISPOSITION_DISCARD;\n}',
#   'graph_idx': 11362,
#   'vul': 1,
#   'id': 4942},
#  {'cve': 'CVE-2015-1274',
#   'cwe_list': ['CWE-254'],
#   'repo_name': 'chromium',
#   'commit_hash': '39841e54180e2583dffa16fbbb9b99fd293821d0',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/39841e54180e2583dffa16fbbb9b99fd293821d0',
#   'func': 'bool DownloadPrefs::EnableAutoOpenBasedOnExtension(\n    const base::FilePath& file_name) {\n  base::FilePath::StringType extension = file_name.Extension();\n  if (extension.empty())\n    return false;\n  DCHECK(extension[0] == base::FilePath::kExtensionSeparator);\n  extension.erase(0, 1);\n\n  auto_open_.insert(extension);\n  SaveAutoOpenState();\n  return true;\n}',
#   'graph_idx': 91858,
#   'vul': 1,
#   'id': 4966},
#  {'cve': 'CVE-2011-2189',
#   'cwe_list': ['CWE-400'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '2b035b39970740722598f7a9d548835f9bdd730f',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=2b035b39970740722598f7a9d548835f9bdd730f',
#   'func': 'void __put_net(struct net *net)\n{\n\t/* Cleanup the network namespace in process context */\n\tINIT_WORK(&net->work, cleanup_net);\n\tqueue_work(netns_wq, &net->work);\n}',
#   'graph_idx': 23466,
#   'vul': 1,
#   'id': 5032},
#  {'cve': 'CVE-2020-36322',
#   'cwe_list': ['CWE-459'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '5d069dbe8aaf2a197142558b6fb2978189ba3454',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=5d069dbe8aaf2a197142558b6fb2978189ba3454',
#   'func': 'static int fuse_xattr_set(const struct xattr_handler *handler,\n\t\t\t  struct dentry *dentry, struct inode *inode,\n\t\t\t  const char *name, const void *value, size_t size,\n\t\t\t  int flags)\n{\n\tif (!value)\n\t\treturn fuse_removexattr(inode, name);\n\n\treturn fuse_setxattr(inode, name, value, size, flags);\n}',
#   'graph_idx': 320537,
#   'vul': 1,
#   'id': 5079},
#  {'cve': 'CVE-2019-17350',
#   'cwe_list': ['CWE-835'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '48584b4b90a9d4ff3fd2545822d487544b7d0718',
#   'git_url': 'https://github.com/xen-project/xen/commit/48584b4b90a9d4ff3fd2545822d487544b7d0718',
#   'func': 'static inline unsigned long __guest_cmpxchg(struct domain *d,\n                                            volatile void *ptr,\n                                            unsigned long old,\n                                            unsigned long new,\n                                            unsigned int size)\n{\n    unsigned long oldval = old;\n\n    if ( __cmpxchg_mb_timeout(ptr, &oldval, new, size,\n                              this_cpu(guest_safe_atomic_max)) )\n        return oldval;\n\n    domain_pause_nosync(d);\n    oldval = __cmpxchg_mb(ptr, old, new, size);\n    domain_unpause(d);\n\n    return oldval;\n}',
#   'graph_idx': 265494,
#   'vul': 1,
#   'id': 5124},
#  {'cve': 'CVE-2018-7323',
#   'cwe_list': ['CWE-834'],
# ...
#   'graph_idx': 139142,
#   'vul': 1,
#   'id': 37187},
#  {'cve': 'CVE-2019-18672',
#   'cwe_list': ['CWE-354'],
#   'repo_name': 'keepkey/keepkey-firmware',
#   'commit_hash': '769714fcb569e7a4faff9530a2d9ac1f9d6e5680',
#   'git_url': 'https://github.com/keepkey/keepkey-firmware/commit/769714fcb569e7a4faff9530a2d9ac1f9d6e5680',
#   'func': 'bool recovery_cipher_abort(void)\n{\n    if (awaiting_character) {\n        awaiting_character = false;\n        return true;\n    }\n    return false;\n}',
#   'graph_idx': 275610,
#   'vul': 1,
#   'id': 37264},
#  {'cve': 'CVE-2016-1646',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'chromium',
#   'commit_hash': '96a2bd8ae8c25e2acbe63319011cbb829b59e3df',
#   'git_url': 'https://chromium.googlesource.com/v8/v8/+/96a2bd8ae8c25e2acbe63319011cbb829b59e3df',
#   'func': 'bool HasConcatSpreadableModifier(Isolate* isolate, Handle<JSArray> obj) {\n  DCHECK(isolate->IsFastArrayConstructorPrototypeChainIntact());\n  Handle<Symbol> key(isolate->factory()->is_concat_spreadable_symbol());\n  Maybe<bool> maybe = JSReceiver::HasProperty(obj, key);\n  return maybe.FromMaybe(false);\n}',
#   'graph_idx': 110809,
#   'vul': 1,
#   'id': 37393},
#  {'cve': 'CVE-2015-1287',
#   'cwe_list': ['CWE-17'],
#   'repo_name': 'chromium',
#   'commit_hash': '0522e0ad97fd5814fc17353f2e373534c4cfebb1',
#   'git_url': 'https://github.com/chromium/chromium/commit/0522e0ad97fd5814fc17353f2e373534c4cfebb1',
#   'func': 'void StyleSheetContents::parseAuthorStyleSheet(const CSSStyleSheetResource* cachedStyleSheet, const SecurityOrigin* securityOrigin)\n{\n    TRACE_EVENT0("blink", "StyleSheetContents::parseAuthorStyleSheet");\n    TRACE_EVENT1(TRACE_DISABLED_BY_DEFAULT("devtools.timeline"), "ParseAuthorStyleSheet", "data", InspectorParseAuthorStyleSheetEvent::data(cachedStyleSheet));\n\n    bool quirksMode = isQuirksModeBehavior(m_parserContext.mode());\n\n    bool enforceMIMEType = !quirksMode;\n    bool hasValidMIMEType = false;\n    String sheetText = cachedStyleSheet->sheetText(enforceMIMEType, &hasValidMIMEType);\n\n    CSSParserContext context(parserContext(), UseCounter::getFrom(this));\n    CSSParser::parseSheet(context, this, sheetText, TextPosition::minimumPosition(), 0, true);\n\n    // If we\'re loading a stylesheet cross-origin, and the MIME type is not standard, require the CSS\n    // to at least start with a syntactically valid CSS rule.\n    // This prevents an attacker playing games by injecting CSS strings into HTML, XML, JSON, etc. etc.\n    if (!hasValidMIMEType && !hasSyntacticallyValidCSSHeader()) {\n        bool isCrossOriginCSS = !securityOrigin || !securityOrigin->canRequest(baseURL());\n        if (isCrossOriginCSS) {\n            clearRules();\n            return;\n        }\n    }\n}',
#   'graph_idx': 92806,
#   'vul': 1,
#   'id': 37432},
#  {'cve': 'CVE-2015-1262',
#   'cwe_list': ['CWE-17'],
#   'repo_name': 'chromium',
#   'commit_hash': 'd8fccaec4e73a9120074293c1997f963f810c9dd',
#   'git_url': 'https://github.com/chromium/chromium/commit/d8fccaec4e73a9120074293c1997f963f810c9dd',
#   'func': 'bool HarfBuzzShaper::shape(GlyphBuffer* glyphBuffer)\n{\n    if (!createHarfBuzzRuns())\n        return false;\n\n    m_totalWidth = 0;\n    if (!shapeHarfBuzzRuns())\n        return false;\n\n    if (glyphBuffer && !fillGlyphBuffer(glyphBuffer))\n        return false;\n\n    return true;\n}',
#   'graph_idx': 89689,
#   'vul': 1,
#   'id': 37495},
#  {'cve': 'CVE-2016-6786',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'f63a8daa5812afef4f06c962351687e1ff9ccb2b',
#   'git_url': 'http://git.kernel.org/cgit/linux/kernel/git/torvalds/linux.git/commit/?id=f63a8daa5812afef4f06c962351687e1ff9ccb2b',
#   'func': 'int perf_event_task_enable(void)\n{\n\tstruct perf_event *event;\n\n\tmutex_lock(&current->perf_event_mutex);\n\tlist_for_each_entry(event, &current->perf_event_list, owner_entry)\n\t\tperf_event_for_each_child(event, perf_event_enable);\n\tmutex_unlock(&current->perf_event_mutex);\n\n\treturn 0;\n}',
#   'graph_idx': 154197,
#   'vul': 1,
#   'id': 37509},
#  {'cve': 'CVE-2019-15215',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'eff73de2b1600ad8230692f00bc0ab49b166512a',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=eff73de2b1600ad8230692f00bc0ab49b166512a',
#   'func': 'static void cpia2_usb_disconnect(struct usb_interface *intf)\n{\n\tstruct camera_data *cam = usb_get_intfdata(intf);\n\tusb_set_intfdata(intf, NULL);\n\n\tDBG("Stopping stream\\n");\n\tcpia2_usb_stream_stop(cam);\n\n\tmutex_lock(&cam->v4l2_lock);\n\tDBG("Unregistering camera\\n");\n\tcpia2_unregister_camera(cam);\n\tv4l2_device_disconnect(&cam->v4l2_dev);\n\tmutex_unlock(&cam->v4l2_lock);\n\tv4l2_device_put(&cam->v4l2_dev);\n\n\tif(cam->buffers) {\n\t\tDBG("Wakeup waiting processes\\n");\n\t\tcam->curbuff->status = FRAME_READY;\n\t\tcam->curbuff->length = 0;\n\t\twake_up_interruptible(&cam->wq_stream);\n\t}\n\n\tLOG("CPiA2 camera disconnected.\\n");\n}',
#   'graph_idx': 259027,
#   'vul': 1,
#   'id': 37534},
#  {'cve': 'CVE-2015-6776',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'pdfium',
#   'commit_hash': '0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'git_url': 'https://pdfium.googlesource.com/pdfium/+/0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'func': 'const opj_jp2_header_handler_t * opj_jp2_find_handler (OPJ_UINT32 p_id)\n{\n\tOPJ_UINT32 i, l_handler_size = sizeof(jp2_header) / sizeof(opj_jp2_header_handler_t);\n\n\tfor (i=0;i<l_handler_size;++i) {\n\t\tif (jp2_header[i].id == p_id) {\n\t\t\treturn &jp2_header[i];\n\t\t}\n\t}\n\treturn NULL;\n}',
#   'graph_idx': 101214,
#   'vul': 1,
#   'id': 37718},
#  {'cve': 'CVE-2020-11049',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'FreeRDP',
#   'commit_hash': 'c367f65d42e0d2e1ca248998175180aa9c2eacd0',
#   'git_url': 'https://github.com/FreeRDP/FreeRDP/commit/c367f65d42e0d2e1ca248998175180aa9c2eacd0',
#   'func': 'static void update_read_synchronize(rdpUpdate* update, wStream* s)\n{\n\tWINPR_UNUSED(update);\n\tStream_Seek_UINT16(s); /* pad2Octets (2 bytes) */\n\t                       /**\n\t                        * The Synchronize Update is an artifact from the\n\t                        * T.128 protocol and should be ignored.\n\t                        */\n}',
#   'graph_idx': 289472,
#   'vul': 1,
#   'id': 37803},
#  {'cve': 'CVE-2019-17350',
#   'cwe_list': ['CWE-835'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '4b0c004beb22777572c1b8bfd1404caddfb268f0',
#   'git_url': 'https://github.com/xen-project/xen/commit/4b0c004beb22777572c1b8bfd1404caddfb268f0',
#   'func': 'static void setup_ports(struct domain *d)\n{\n    unsigned int port;\n\n    /*\n     * For each port that is already bound:\n     *\n     * - save its pending state.\n     * - set default priority.\n     */\n    for ( port = 1; port < d->max_evtchns; port++ )\n    {\n        struct evtchn *evtchn;\n\n        if ( !port_is_valid(d, port) )\n            break;\n\n        evtchn = evtchn_from_port(d, port);\n\n        if ( test_bit(port, &shared_info(d, evtchn_pending)) )\n            evtchn->pending = 1;\n\n        evtchn_fifo_set_priority(d, evtchn, EVTCHN_FIFO_PRIORITY_DEFAULT);\n    }\n}',
#   'graph_idx': 265723,
#   'vul': 1,
#   'id': 37827},
#  {'cve': 'CVE-2018-19044',
#   'cwe_list': ['CWE-59'],
#   'repo_name': 'acassen/keepalived',
#   'commit_hash': '04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'git_url': 'https://github.com/acassen/keepalived/commit/04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'func': 'void\nvrrp_print_data(void)\n{\n\tFILE *file = fopen (dump_file, "w");\n\n\tif (!file) {\n\t\tlog_message(LOG_INFO, "Can\'t open %s (%d: %s)",\n\t\t\tdump_file, errno, strerror(errno));\n\t\treturn;\n\t}\n\n\tdump_data_vrrp(file);\n\n\tfclose(file);\n}',
#   'graph_idx': 238622,
#   'vul': 1,
#   'id': 37955},
#  {'cve': 'CVE-2011-2200',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'dbus',
#   'commit_hash': '6519a1f77c61d753d4c97efd6e15630eb275336e',
#   'git_url': 'http://cgit.freedesktop.org/dbus/dbus/commit/?h=dbus-1.2&id=6519a1f77c61d753d4c97efd6e15630eb275336e',
#   'func': 'void\n_dbus_header_byteswap (DBusHeader *header,\n                       int         new_order)\n{\n  if (header->byte_order == new_order)\n    return;\n\n  _dbus_marshal_byteswap (&_dbus_header_signature_str,\n                          0, header->byte_order,\n                          new_order,\n                          &header->data, 0);\n\n  header->byte_order = new_order;\n}',
#   'graph_idx': 22454,
#   'vul': 1,
#   'id': 38031},
#  {'cve': 'CVE-2016-1621',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'android',
#   'commit_hash': '04839626ed859623901ebd3a5fd483982186b59d',
#   'git_url': 'https://android.googlesource.com/platform/external/libvpx/+/04839626ed859623901ebd3a5fd483982186b59d',
#   'func': 'const char* Chapters::Display::GetString() const\n{\n    return m_string;\n}',
#   'graph_idx': 110306,
#   'vul': 1,
#   'id': 38046},
#  {'cve': 'CVE-2017-6850',
#   'cwe_list': ['CWE-476'],
#   'repo_name': 'mdadams/jasper',
#   'commit_hash': 'e96fc4fdd525fa0ede28074a7e2b1caf94b58b0d',
#   'git_url': 'https://github.com/mdadams/jasper/commit/e96fc4fdd525fa0ede28074a7e2b1caf94b58b0d',
#   'func': 'jp2_box_t *jp2_box_create(int type)\n{\n\tjp2_box_t *box;\n\tjp2_boxinfo_t *boxinfo;\n\n\tif (!(box = jas_malloc(sizeof(jp2_box_t)))) {\n\t\treturn 0;\n\t}\n\tmemset(box, 0, sizeof(jp2_box_t));\n\tbox->type = type;\n\tbox->len = 0;\n\tif (!(boxinfo = jp2_boxinfolookup(type))) {\n\t\treturn 0;\n\t}\n\tbox->info = boxinfo;\n\tbox->ops = &boxinfo->ops;\n\treturn box;\n}',
#   'graph_idx': 166427,
#   'vul': 1,
#   'id': 38049},
#  {'cve': 'CVE-2015-1242',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '35b44e5fa8542a64117257465b5810e7afca0e27',
#   'git_url': 'https://chromium.googlesource.com/v8/v8/+/35b44e5fa8542a64117257465b5810e7afca0e27',
#   'func': 'void ReduceTransitionElementsKind(HTransitionElementsKind* instr) {\n    HValue* object = instr->object()->ActualValue();\n    HCheckTableEntry* entry = Find(object);\n    // Can only learn more about an object that already has a known set of maps.\n    if (entry == NULL) return;\n    EnsureChecked(entry, object, instr);\n    if (entry->maps_->Contains(instr->original_map())) {\n      // If the object has the original map, it will be transitioned.\n      UniqueSet<Map>* maps = entry->maps_->Copy(zone());\n      maps->Remove(instr->original_map());\n      maps->Add(instr->transitioned_map(), zone());\n      entry->maps_ = maps;\n    } else {\n      // Object does not have the given map, thus the transition is redundant.\n      instr->DeleteAndReplaceWith(object);\n      INC_STAT(transitions_);\n    }\n  }',
#   'graph_idx': 88577,
#   'vul': 1,
#   'id': 38067},
#  {'cve': 'CVE-2015-6776',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'pdfium',
#   'commit_hash': '0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'git_url': 'https://pdfium.googlesource.com/pdfium/+/0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'func': 'const opj_dec_memory_marker_handler_t * opj_j2k_get_marker_handler (OPJ_UINT32 p_id)\n{\n        const opj_dec_memory_marker_handler_t *e;\n        for (e = j2k_memory_marker_handler_tab; e->id != 0; ++e) {\n                if (e->id == p_id) {\n                        break; /* we find a handler corresponding to the marker ID*/\n                }\n        }\n        return e;\n}',
#   'graph_idx': 101623,
#   'vul': 1,
#   'id': 38368},
#  {'cve': 'CVE-2020-36387',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '6d816e088c359866f9867057e04f244c608c42fe',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=6d816e088c359866f9867057e04f244c608c42fe',
#   'func': 'static bool io_rw_reissue(struct io_kiocb *req, long res)\n{\n#ifdef CONFIG_BLOCK\n\tint ret;\n\n\tif ((res != -EAGAIN && res != -EOPNOTSUPP) || io_wq_current_is_worker())\n\t\treturn false;\n\n\tinit_task_work(&req->task_work, io_rw_resubmit);\n\tret = io_req_task_work_add(req, &req->task_work);\n\tif (!ret)\n\t\treturn true;\n#endif\n\treturn false;\n}',
#   'graph_idx': 326751,
#   'vul': 1,
#   'id': 38405},
#  {'cve': 'CVE-2017-11171',
#   'cwe_list': ['CWE-835'],
#   'repo_name': 'GNOME/gnome-session',
#   'commit_hash': 'b0dc999e0b45355314616321dbb6cb71e729fc9d',
#   'git_url': 'https://github.com/GNOME/gnome-session/commit/b0dc999e0b45355314616321dbb6cb71e729fc9d',
#   'func': 'static void\nsetup_connection (GsmXSMPClient *client)\n{\n        GIOChannel    *channel;\n        int            fd;\n\n        g_debug ("GsmXSMPClient: Setting up new connection");\n\n        fd = IceConnectionNumber (client->priv->ice_connection);\n        fcntl (fd, F_SETFD, fcntl (fd, F_GETFD, 0) | FD_CLOEXEC);\n        channel = g_io_channel_unix_new (fd);\n        client->priv->watch_id = g_io_add_watch (channel,\n                                                 G_IO_IN | G_IO_ERR,\n                                                 (GIOFunc)client_iochannel_watch,\n                                                 client);\n        g_io_channel_unref (channel);\n\n        client->priv->protocol_timeout = g_timeout_add_seconds (5,\n                                                                (GSourceFunc)_client_protocol_timeout,\n                                                                client);\n\n        set_description (client);\n\n        g_debug ("GsmXSMPClient: New client \'%s\'", client->priv->description);\n}',
#   'graph_idx': 185310,
#   'vul': 1,
#   'id': 38473},
#  {'cve': 'CVE-2018-19628',
#   'cwe_list': ['CWE-369'],
#   'repo_name': 'wireshark',
#   'commit_hash': '212b18825d9b668cda23d334c48867dfa66b2b36',
#   'git_url': 'https://github.com/wireshark/wireshark/commit/212b18825d9b668cda23d334c48867dfa66b2b36',
#   'func': 'static void\ndecode_color_temperature(gchar *s, guint16 value)\n{\n    g_snprintf(s, ITEM_LABEL_LENGTH, "%d [Mired] (%d [K])", value, 1000000/value);\n    return;\n}',
#   'graph_idx': 239578,
#   'vul': 1,
#   'id': 38506},
#  {'cve': 'CVE-2011-1488',
#   'cwe_list': ['CWE-772'],
#   'repo_name': 'rsyslog',
#   'commit_hash': '1ef709cc97d54f74d3fdeb83788cc4b01f4c6a2a',
#   'git_url': 'https://github.com/rsyslog/rsyslog/commit/1ef709cc97d54f74d3fdeb83788cc4b01f4c6a2a',
#   'func': 'static inline rsRetVal\nbatchInit(batch_t *pBatch, int maxElem) {\n\tDEFiRet;\n\tpBatch->maxElem = maxElem;\n\tCHKmalloc(pBatch->pElem = calloc((size_t)maxElem, sizeof(batch_obj_t)));\n\t// TODO: replace calloc by inidividual writes?\nfinalize_it:\n\tRETiRet;\n}',
#   'graph_idx': 270090,
#   'vul': 1,
#   'id': 38579},
#  {'cve': 'CVE-2018-10853',
#   'cwe_list': ['CWE-269'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '3c9fa24ca7c9c47605672916491f79e8ccacb9e6',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=3c9fa24ca7c9c47605672916491f79e8ccacb9e6',
#   'func': 'static int linear_read_system(struct x86_emulate_ctxt *ctxt, ulong linear,\n\t\t\t      void *data, unsigned size)\n{\n\treturn ctxt->ops->read_std(ctxt, linear, data, size, &ctxt->exception);\n}',
#   'graph_idx': 234202,
#   'vul': 1,
#   'id': 38624},
#  {'cve': 'CVE-2018-20748',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'LibVNC/libvncserver',
#   'commit_hash': 'e34bcbb759ca5bef85809967a268fdf214c1ad2c',
#   'git_url': 'https://github.com/LibVNC/libvncserver/commit/e34bcbb759ca5bef85809967a268fdf214c1ad2c',
#   'func': 'static void\nReadReason(rfbClient* client)\n{\n    uint32_t reasonLen;\n    char *reason;\n\n    /* we have an error following */\n    if (!ReadFromRFBServer(client, (char *)&reasonLen, 4)) return;\n    reasonLen = rfbClientSwap32IfLE(reasonLen);\n    reason = malloc((uint64_t)reasonLen+1);\n    if (!ReadFromRFBServer(client, reason, reasonLen)) { free(reason); return; }\n    reason[reasonLen]=0;\n    rfbClientLog("VNC connection failed: %s\\n",reason);\n    free(reason);\n}',
#   'graph_idx': 244160,
#   'vul': 1,
#   'id': 38673}]

# %%
balanced_small_test_set = pd.concat(
    [small_test_set_df[small_test_set_df['vul'] == 0].sample(100,random_state=2020),
    small_test_set_df[small_test_set_df['vul'] == 1].sample(100,random_state=2021)]
).sample(frac=1,random_state=2022)
balanced_small_test_set.to_dict('records')
# Out:
# [{'cve': 'CVE-2014-0064',
#   'cwe_list': ['CWE-189'],
#   'repo_name': 'postgres',
#   'commit_hash': '31400a673325147e1205326008e32135a78b4d8a',
#   'git_url': 'https://github.com/postgres/postgres/commit/31400a673325147e1205326008e32135a78b4d8a',
#   'func': "static void\nfindoprnd(ITEM *ptr, int32 *pos)\n{\n\tif (ptr[*pos].type == VAL || ptr[*pos].type == VALTRUE)\n\t{\n\t\tptr[*pos].left = 0;\n\t\t(*pos)++;\n\t}\n\telse if (ptr[*pos].val == (int32) '!')\n\t{\n\t\tptr[*pos].left = 1;\n\t\t(*pos)++;\n\t\tfindoprnd(ptr, pos);\n\t}\n\telse\n\t{\n\t\tITEM\t   *curitem = &ptr[*pos];\n\t\tint32\t\ttmp = *pos;\n\n\t\t(*pos)++;\n\t\tfindoprnd(ptr, pos);\n\t\tcuritem->left = *pos - tmp;\n\t\tfindoprnd(ptr, pos);\n\t}\n}",
#   'graph_idx': 64081,
#   'vul': 1,
#   'id': 36335},
#  {'cve': 'CVE-2019-19536',
#   'cwe_list': ['CWE-909'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ead16e53c2f0ed946d82d4037c630e2f60f4ab69',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=ead16e53c2f0ed946d82d4037c630e2f60f4ab69',
#   'func': 'static u8 *pcan_msg_init(struct pcan_usb_pro_msg *pm, void *buffer_addr,\n\t\t\t int buffer_size)\n{\n\tif (buffer_size < PCAN_USBPRO_MSG_HEADER_LEN)\n\t\treturn NULL;\n\n\tpm->u.rec_buffer = (u8 *)buffer_addr;\n\tpm->rec_buffer_size = pm->rec_buffer_len = buffer_size;\n\tpm->rec_ptr = pm->u.rec_buffer + PCAN_USBPRO_MSG_HEADER_LEN;\n\n\treturn pm->rec_ptr;\n}',
#   'graph_idx': 274925,
#   'vul': 0,
#   'id': 3708},
#  {'cve': 'CVE-2016-9395',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'mdadams/jasper',
#   'commit_hash': 'd42b2388f7f8e0332c846675133acea151fc557a',
#   'git_url': 'https://github.com/mdadams/jasper/commit/d42b2388f7f8e0332c846675133acea151fc557a',
#   'func': 'static inline ulong encode_twos_comp(long n, int prec)\n{\n\tulong result;\n\tassert(prec >= 2);\n\tjas_eprintf("warning: support for signed data is untested\\n");\n\t// NOTE: Is this correct?\n\tif (n < 0) {\n\t\tresult = -n;\n\t\tresult = (result ^ 0xffffffffUL) + 1;\n\t\tresult &= (1 << prec) - 1;\n\t} else {\n\t\tresult = n;\n\t}\n\treturn result;\n}',
#   'graph_idx': 169326,
#   'vul': 1,
#   'id': 36991},
#  {'cve': 'CVE-2016-2430',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'android',
#   'commit_hash': 'ad54cfed4516292654c997910839153264ae00a0',
#   'git_url': 'https://android.googlesource.com/platform/system/core/+/ad54cfed4516292654c997910839153264ae00a0',
#   'func': 'std::string Backtrace::GetFunctionName(uintptr_t pc, uintptr_t* offset) {\n  std::string func_name = GetFunctionNameRaw(pc, offset);\n  if (!func_name.empty()) {\n#if defined(__APPLE__)\n    // Mac OS\' __cxa_demangle demangles "f" as "float"; last tested on 10.7.\n    if (func_name[0] != \'_\') {\n      return func_name;\n    }\n#endif\n    char* name = __cxa_demangle(func_name.c_str(), 0, 0, 0);\n    if (name) {\n      func_name = name;\n      free(name);\n    }\n  }\n  return func_name;\n}',
#   'graph_idx': 117839,
#   'vul': 1,
#   'id': 14744},
#  {'cve': 'CVE-2018-7335',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'wireshark',
#   'commit_hash': 'a2901dcf45c9f1b07abfbf2a0b0cd654371d72a4',
#   'git_url': 'https://github.com/wireshark/wireshark/commit/a2901dcf45c9f1b07abfbf2a0b0cd654371d72a4',
#   'func': 'gchar*\nget_key_string(decryption_key_t* dk)\n{\n    gchar* output_string = NULL;\n\n    if(dk == NULL || dk->key == NULL)\n        return NULL;\n\n    switch(dk->type) {\n        case AIRPDCAP_KEY_TYPE_WEP:\n            output_string = g_strdup(dk->key->str);\n            break;\n        case AIRPDCAP_KEY_TYPE_WPA_PWD:\n            if(dk->ssid == NULL)\n                output_string = g_strdup(dk->key->str);\n            else\n                output_string = g_strdup_printf("%s:%s",\n                    dk->key->str, format_uri(dk->ssid, ":"));\n            break;\n        case AIRPDCAP_KEY_TYPE_WPA_PMK:\n            output_string = g_strdup(dk->key->str);\n            break;\n        default:\n            return NULL;\n    }\n\n    return output_string;\n}',
#   'graph_idx': 211000,
#   'vul': 0,
#   'id': 18986},
#  {'cve': 'CVE-2019-17545',
#   'cwe_list': ['CWE-415'],
#   'repo_name': 'OSGeo/gdal',
#   'commit_hash': '148115fcc40f1651a5d15fa34c9a8c528e7147bb',
#   'git_url': 'https://github.com/OSGeo/gdal/commit/148115fcc40f1651a5d15fa34c9a8c528e7147bb',
#   'func': 'static void* OGRExpatRealloc( void *ptr, size_t size )\n{\n    if( CanAlloc(size) )\n        return realloc(ptr, size);\n\n    free(ptr);\n    return nullptr;\n}',
#   'graph_idx': 267455,
#   'vul': 1,
#   'id': 18475},
#  {'cve': 'CVE-2016-5172',
#   'cwe_list': ['CWE-200'],
#   'repo_name': 'chromium',
#   'commit_hash': '0e14baf712955a1993f742647bb2adc293702b80',
#   'git_url': 'https://chromium.googlesource.com/v8/v8/+/0e14baf712955a1993f742647bb2adc293702b80',
#   'func': 'void Rewriter::VisitVariableProxy(VariableProxy* proxy) {\n  if (proxy->is_resolved()) {\n    Variable* var = proxy->var();\n    if (var->mode() != TEMPORARY) return;\n    int index = old_scope_->RemoveTemporary(var);\n    if (index >= 0) {\n      temps_.push_back(std::make_pair(var, index));\n    }\n  } else if (old_scope_->RemoveUnresolved(proxy)) {\n    new_scope_->AddUnresolved(proxy);\n  }\n}',
#   'graph_idx': 147014,
#   'vul': 1,
#   'id': 13565},
#  {'cve': 'CVE-2020-27790',
#   'cwe_list': ['CWE-369'],
#   'repo_name': 'upx',
#   'commit_hash': 'eb90eab6325d009004ffb155e3e33f22d4d3ca26',
#   'git_url': 'https://github.com/upx/upx/commit/eb90eab6325d009004ffb155e3e33f22d4d3ca26',
#   'func': 'int const *\nPackLinuxElf32x86::getFilters() const\n{\n    static const int filters[] = {\n        0x49, 0x46,\n// FIXME 2002-11-11: We use stub/fold_elf86.asm, which calls the\n// decompressor multiple times, and unfilter is independent of decompress.\n// Currently only filters 0x49, 0x46, 0x80..0x87 can handle this;\n// and 0x80..0x87 are regarded as "untested".\n#if 0\n        0x26, 0x24, 0x11, 0x14, 0x13, 0x16, 0x25, 0x15, 0x12,\n#endif\n#if 0\n        0x83, 0x36, 0x26,\n              0x86, 0x80,\n        0x84, 0x87, 0x81,\n        0x82, 0x85,\n        0x24, 0x16, 0x13, 0x14, 0x11, 0x25, 0x15, 0x12,\n#endif\n    FT_END };\n    return filters;\n}',
#   'graph_idx': 387988,
#   'vul': 0,
#   'id': 34256},
#  {'cve': 'CVE-2019-20095',
#   'cwe_list': ['CWE-401'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '003b686ace820ce2d635a83f10f2d7f9c147dabc',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=003b686ace820ce2d635a83f10f2d7f9c147dabc',
#   'func': 'int mwifiex_init_channel_scan_gap(struct mwifiex_adapter *adapter)\n{\n\tu32 n_channels_bg, n_channels_a = 0;\n\n\tn_channels_bg = mwifiex_band_2ghz.n_channels;\n\n\tif (adapter->config_bands & BAND_A)\n\t\tn_channels_a = mwifiex_band_5ghz.n_channels;\n\n\t/* allocate twice the number total channels, since the driver issues an\n\t * additional active scan request for hidden SSIDs on passive channels.\n\t */\n\tadapter->num_in_chan_stats = 2 * (n_channels_bg + n_channels_a);\n\tadapter->chan_stats = vmalloc(array_size(sizeof(*adapter->chan_stats),\n\t\t\t\t\t\t adapter->num_in_chan_stats));\n\n\tif (!adapter->chan_stats)\n\t\treturn -ENOMEM;\n\n\treturn 0;\n}',
#   'graph_idx': 279971,
#   'vul': 0,
#   'id': 22703},
#  {'cve': 'CVE-2018-19628',
#   'cwe_list': ['CWE-369'],
#   'repo_name': 'wireshark',
#   'commit_hash': '212b18825d9b668cda23d334c48867dfa66b2b36',
#   'git_url': 'https://github.com/wireshark/wireshark/commit/212b18825d9b668cda23d334c48867dfa66b2b36',
#   'func': 'static void\ndecode_color_temperature(gchar *s, guint16 value)\n{\n    g_snprintf(s, ITEM_LABEL_LENGTH, "%d [Mired] (%d [K])", value, 1000000/value);\n    return;\n}',
#   'graph_idx': 239578,
#   'vul': 1,
#   'id': 38506},
#  {'cve': 'CVE-2010-4818',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'xorg/xserver',
#   'commit_hash': '6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'git_url': 'http://cgit.freedesktop.org/xorg/xserver/commit?id=6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'func': 'int __glXDispSwap_QueryVersion(__GLXclientState *cl, GLbyte *pc)\n{\n    xGLXQueryVersionReq *req = (xGLXQueryVersionReq *) pc;\n    __GLX_DECLARE_SWAP_VARIABLES;\n\n    __GLX_SWAP_SHORT(&req->length);\n    __GLX_SWAP_INT(&req->majorVersion);\n    __GLX_SWAP_INT(&req->minorVersion);\n\n    return __glXDisp_QueryVersion(cl, pc);\n}',
#   'graph_idx': 34416,
#   'vul': 1,
#   'id': 12751},
#  {'cve': 'CVE-2013-0859',
#   'cwe_list': ['CWE-189'],
#   'repo_name': 'ffmpeg',
#   'commit_hash': '6d1c5ea04af3e345232aa70c944de961061dab2d',
#   'git_url': 'http://git.videolan.org/?p=ffmpeg.git;a=commit;h=6d1c5ea04af3e345232aa70c944de961061dab2d',
#   'func': 'static int add_doubles_metadata(int count,\n                                const char *name, const char *sep,\n                                TiffContext *s)\n{\n    char *ap;\n    int i;\n    double *dp;\n\n    if (count >= INT_MAX / sizeof(int64_t))\n        return AVERROR_INVALIDDATA;\n    if (bytestream2_get_bytes_left(&s->gb) < count * sizeof(int64_t))\n        return AVERROR_INVALIDDATA;\n\n    dp = av_malloc(count * sizeof(double));\n    if (!dp)\n        return AVERROR(ENOMEM);\n\n    for (i = 0; i < count; i++)\n        dp[i] = tget_double(&s->gb, s->le);\n    ap = doubles2str(dp, count, sep);\n    av_freep(&dp);\n    if (!ap)\n        return AVERROR(ENOMEM);\n    av_dict_set(&s->picture.metadata, name, ap, AV_DICT_DONT_STRDUP_VAL);\n    return 0;\n}',
#   'graph_idx': 53693,
#   'vul': 1,
#   'id': 13470},
#  {'cve': 'CVE-2014-9065',
#   'cwe_list': ['CWE-17'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '2a549b9c8aa48dc39d7c97e5a93978b781b3a1db',
#   'git_url': 'https://github.com/xen-project/xen/commit/2a549b9c8aa48dc39d7c97e5a93978b781b3a1db',
#   'func': 'int _write_trylock(rwlock_t *lock)\n{\n    check_lock(&lock->debug);\n    if ( !_raw_write_trylock(&lock->raw) )\n        return 0;\n    preempt_disable();\n    return 1;\n}',
#   'graph_idx': 81021,
#   'vul': 1,
#   'id': 14044},
#  {'cve': 'CVE-2018-19044',
#   'cwe_list': ['CWE-59'],
#   'repo_name': 'acassen/keepalived',
#   'commit_hash': '04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'git_url': 'https://github.com/acassen/keepalived/commit/04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'func': 'void\nvrrp_print_data(void)\n{\n\tFILE *file = fopen (dump_file, "w");\n\n\tif (!file) {\n\t\tlog_message(LOG_INFO, "Can\'t open %s (%d: %s)",\n\t\t\tdump_file, errno, strerror(errno));\n\t\treturn;\n\t}\n\n\tdump_data_vrrp(file);\n\n\tfclose(file);\n}',
#   'graph_idx': 238622,
#   'vul': 1,
#   'id': 37955},
#  {'cve': 'CVE-2022-28893',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '1a3b1bba7c7a5eb8a11513cf88427cb9d77bc60a',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=1a3b1bba7c7a5eb8a11513cf88427cb9d77bc60a',
#   'func': 'int nfs4_proc_get_lease_time(struct nfs_client *clp, struct nfs_fsinfo *fsinfo)\n{\n\tstruct nfs4_get_lease_time_args args;\n\tstruct nfs4_get_lease_time_res res = {\n\t\t.lr_fsinfo = fsinfo,\n\t};\n\tstruct nfs4_get_lease_time_data data = {\n\t\t.args = &args,\n\t\t.res = &res,\n\t\t.clp = clp,\n\t};\n\tstruct rpc_message msg = {\n\t\t.rpc_proc = &nfs4_procedures[NFSPROC4_CLNT_GET_LEASE_TIME],\n\t\t.rpc_argp = &args,\n\t\t.rpc_resp = &res,\n\t};\n\tstruct rpc_task_setup task_setup = {\n\t\t.rpc_client = clp->cl_rpcclient,\n\t\t.rpc_message = &msg,\n\t\t.callback_ops = &nfs4_get_lease_time_ops,\n\t\t.callback_data = &data,\n\t\t.flags = RPC_TASK_TIMEOUT,\n\t};\n\n\tnfs4_init_sequence(&args.la_seq_args, &res.lr_seq_res, 0, 1);\n\treturn nfs4_call_sync_custom(&task_setup);\n}',
#   'graph_idx': 371334,
#   'vul': 0,
#   'id': 8358},
#  {'cve': 'CVE-2010-4818',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'xorg/xserver',
#   'commit_hash': '6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'git_url': 'http://cgit.freedesktop.org/xorg/xserver/commit?id=6c69235a9dfc52e4b4e47630ff4bab1a820eb543',
#   'func': 'int __glXDispSwap_CreateContextWithConfigSGIX(__GLXclientState *cl, GLbyte *pc)\n{\n    xGLXCreateContextWithConfigSGIXReq *req =\n\t(xGLXCreateContextWithConfigSGIXReq *) pc;\n    __GLX_DECLARE_SWAP_VARIABLES;\n\n    __GLX_SWAP_SHORT(&req->length);\n    __GLX_SWAP_INT(&req->context);\n    __GLX_SWAP_INT(&req->fbconfig);\n    __GLX_SWAP_INT(&req->screen);\n    __GLX_SWAP_INT(&req->renderType);\n    __GLX_SWAP_INT(&req->shareList);\n\n    return __glXDisp_CreateContextWithConfigSGIX(cl, pc);\n}',
#   'graph_idx': 34450,
#   'vul': 1,
#   'id': 32963},
#  {'cve': 'CVE-2016-3913',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'android',
#   'commit_hash': '0c3b93c8c2027e74af642967eee5c142c8fd185d',
#   'git_url': 'https://android.googlesource.com/platform/frameworks/av/+/0c3b93c8c2027e74af642967eee5c142c8fd185d',
#   'func': 'status_t MediaPlayerService::Client::stop()\n{\n    ALOGV("[%d] stop", mConnId);\n    sp<MediaPlayerBase> p = getPlayer();\n    if (p == 0) return UNKNOWN_ERROR;\n    return p->stop();\n}',
#   'graph_idx': 148689,
#   'vul': 0,
#   'id': 38418},
#  {'cve': 'CVE-2014-3479',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'file',
#   'commit_hash': '36fadd29849b8087af9f4586f89dbf74ea45be67',
#   'git_url': 'https://github.com/file/file/commit/36fadd29849b8087af9f4586f89dbf74ea45be67',
#   'func': 'static int\ncdf_check_stream_offset(const cdf_stream_t *sst, const cdf_header_t *h,\n    const void *p, size_t tail, int line)\n{\n\tconst char *b = (const char *)sst->sst_tab;\n\tconst char *e = ((const char *)p) + tail;\n\t(void)&line;\n\tif (e >= b && (size_t)(e - b) <= CDF_SEC_SIZE(h) * sst->sst_len)\n\t\treturn 0;\n\tDPRINTF(("%d: offset begin %p < end %p || %" SIZE_T_FORMAT "u"\n\t    " > %" SIZE_T_FORMAT "u [%" SIZE_T_FORMAT "u %"\n\t    SIZE_T_FORMAT "u]\\n", line, b, e, (size_t)(e - b),\n\t    CDF_SEC_SIZE(h) * sst->sst_len, CDF_SEC_SIZE(h), sst->sst_len));\n\terrno = EFTYPE;\n\treturn -1;\n}',
#   'graph_idx': 69499,
#   'vul': 1,
#   'id': 4735},
#  {'cve': 'CVE-2018-14466',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'the-tcpdump-group/tcpdump',
#   'commit_hash': 'c24922e692a52121e853a84ead6b9337f4c08a94',
#   'git_url': 'https://github.com/the-tcpdump-group/tcpdump/commit/c24922e692a52121e853a84ead6b9337f4c08a94',
#   'func': 'static void\nrx_cache_insert(netdissect_options *ndo,\n                const u_char *bp, const struct ip *ip, int dport)\n{\n\tstruct rx_cache_entry *rxent;\n\tconst struct rx_header *rxh = (const struct rx_header *) bp;\n\n\tif (ndo->ndo_snapend - bp + 1 <= (int)(sizeof(struct rx_header) + sizeof(int32_t)))\n\t\treturn;\n\n\trxent = &rx_cache[rx_cache_next];\n\n\tif (++rx_cache_next >= RX_CACHE_SIZE)\n\t\trx_cache_next = 0;\n\n\trxent->callnum = EXTRACT_32BITS(&rxh->callNumber);\n\tUNALIGNED_MEMCPY(&rxent->client, &ip->ip_src, sizeof(uint32_t));\n\tUNALIGNED_MEMCPY(&rxent->server, &ip->ip_dst, sizeof(uint32_t));\n\trxent->dport = dport;\n\trxent->serviceId = EXTRACT_32BITS(&rxh->serviceId);\n\trxent->opcode = EXTRACT_32BITS(bp + sizeof(struct rx_header));\n}',
#   'graph_idx': 264787,
#   'vul': 1,
#   'id': 13388},
#  {'cve': 'CVE-2020-36557',
#   'cwe_list': ['CWE-416', 'CWE-362'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ca4463bf8438b403596edd0ec961ca0d4fbe0220',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=ca4463bf8438b403596edd0ec961ca0d4fbe0220',
#   'func': 'static void vt_disallocate_all(void)\n{\n\tstruct vc_data *vc[MAX_NR_CONSOLES];\n\tint i;\n\n\tconsole_lock();\n\tfor (i = 1; i < MAX_NR_CONSOLES; i++)\n\t\tif (!vt_busy(i))\n\t\t\tvc[i] = vc_deallocate(i);\n\t\telse\n\t\t\tvc[i] = NULL;\n\tconsole_unlock();\n\n\tfor (i = 1; i < MAX_NR_CONSOLES; i++) {\n\t\tif (vc[i] && i >= MIN_NR_CONSOLES) {\n\t\t\ttty_port_destroy(&vc[i]->port);\n\t\t\tkfree(vc[i]);\n\t\t}\n\t}\n}',
#   'graph_idx': 386043,
#   'vul': 1,
#   'id': 3100},
#  {'cve': 'CVE-2017-5547',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '6d104af38b570d37aa32a5803b04c354f8ed513d',
#   'git_url': 'http://git.kernel.org/cgit/linux/kernel/git/torvalds/linux.git/commit/?id=6d104af38b570d37aa32a5803b04c354f8ed513d',
#   'func': 'static ssize_t k90_show_current_profile(struct device *dev,\n\t\t\t\t\tstruct device_attribute *attr,\n\t\t\t\t\tchar *buf)\n{\n\tint ret;\n\tstruct usb_interface *usbif = to_usb_interface(dev->parent);\n\tstruct usb_device *usbdev = interface_to_usbdev(usbif);\n\tint current_profile;\n\tchar data[8];\n\n\tret = usb_control_msg(usbdev, usb_rcvctrlpipe(usbdev, 0),\n\t\t\t      K90_REQUEST_STATUS,\n\t\t\t      USB_DIR_IN | USB_TYPE_VENDOR |\n\t\t\t      USB_RECIP_DEVICE, 0, 0, data, 8,\n\t\t\t      USB_CTRL_SET_TIMEOUT);\n\tif (ret < 0) {\n\t\tdev_warn(dev, "Failed to get K90 initial state (error %d).\\n",\n\t\t\t ret);\n\t\treturn -EIO;\n\t}\n\tcurrent_profile = data[7];\n\tif (current_profile < 1 || current_profile > 3) {\n\t\tdev_warn(dev, "Read invalid current profile: %02hhx.\\n",\n\t\t\t data[7]);\n\t\treturn -EIO;\n\t}\n\n\treturn snprintf(buf, PAGE_SIZE, "%d\\n", current_profile);\n}',
#   'graph_idx': 159475,
#   'vul': 1,
#   'id': 5294},
#  {'cve': 'CVE-2016-5132',
#   'cwe_list': ['CWE-254'],
#   'repo_name': 'chromium',
#   'commit_hash': '8353baf8d1504dbdd4ad7584ff2466de657521cd',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/8353baf8d1504dbdd4ad7584ff2466de657521cd',
#   'func': 'void Document::setUseSecureKeyboardEntryWhenActive(bool usesSecureKeyboard)\n{\n    if (m_useSecureKeyboardEntryWhenActive == usesSecureKeyboard)\n        return;\n\n    m_useSecureKeyboardEntryWhenActive = usesSecureKeyboard;\n    m_frame->selection().updateSecureKeyboardEntryIfActive();\n}',
#   'graph_idx': 138010,
#   'vul': 0,
#   'id': 35241},
#  {'cve': 'CVE-2019-20915',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'LibreDWG/libredwg',
#   'commit_hash': '95cc9300430d35feb05b06a9badf678419463dbe',
#   'git_url': 'https://github.com/LibreDWG/libredwg/commit/95cc9300430d35feb05b06a9badf678419463dbe',
#   'func': 'void\nbit_write_UMC (Bit_Chain *dat, BITCODE_UMC val)\n{\n  int i, j;\n  int negative;\n  unsigned char byte[5];\n  BITCODE_UMC mask;\n  BITCODE_UMC value;\n\n  value = val;\n  mask = 0x0000007f;\n  for (i = 4, j = 0; i >= 0; i--, j += 7)\n    {\n      byte[i] = (unsigned char)((value & mask) >> j);\n      byte[i] |= 0x80;\n      mask = mask << 7;\n    }\n  for (i = 0; i < 4; i++)\n    if (byte[i] & 0x7f)\n      break;\n\n  if (byte[i] & 0x40)\n    i--;\n  byte[i] &= 0x7f;\n  for (j = 4; j >= i; j--)\n    bit_write_RC (dat, byte[j]);\n}',
#   'graph_idx': 296496,
#   'vul': 1,
#   'id': 35904},
#  {'cve': 'CVE-2022-4095',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'c53b3dcb9942b8ed7f81ee3921c4085d87070c73',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=c53b3dcb9942b8ed7f81ee3921c4085d87070c73',
#   'func': 'static u8 read_rfreg_hdl(struct _adapter *padapter, u8 *pbuf)\n{\n\tu32 val;\n\tvoid (*pcmd_callback)(struct _adapter *dev, struct cmd_obj *pcmd);\n\tstruct cmd_obj *pcmd  = (struct cmd_obj *)pbuf;\n\n\tif (pcmd->rsp && pcmd->rspsz > 0)\n\t\tmemcpy(pcmd->rsp, (u8 *)&val, pcmd->rspsz);\n\tpcmd_callback = cmd_callback[pcmd->cmdcode].callback;\n\tif (!pcmd_callback)\n\t\tr8712_free_cmd_obj(pcmd);\n\telse\n\t\tpcmd_callback(padapter, pcmd);\n\treturn H2C_SUCCESS;\n}',
#   'graph_idx': 427838,
#   'vul': 0,
#   'id': 18959},
#  {'cve': 'CVE-2021-40568',
#   'cwe_list': ['CWE-120'],
#   'repo_name': 'gpac',
#   'commit_hash': 'f1ae01d745200a258cdf62622f71754c37cb6c30',
#   'git_url': 'https://github.com/gpac/gpac/commit/f1ae01d745200a258cdf62622f71754c37cb6c30',
#   'func': 'static void vp9_render_size(GF_BitStream *bs, int FrameWidth, int FrameHeight, int *renderWidth, int *renderHeight)\n{\n\tBool render_and_frame_size_different = gf_bs_read_int_log(bs, 1, "render_and_frame_size_different");\n\tif (render_and_frame_size_different == 1) {\n\t\tint render_width_minus_1 = gf_bs_read_int_log(bs, 16, "render_width_minus_1");\n\t\tint render_height_minus_1 = gf_bs_read_int_log(bs, 16, "render_height_minus_1");\n\t\t*renderWidth = render_width_minus_1 + 1;\n\t\t*renderHeight = render_height_minus_1 + 1;\n\t}\n\telse {\n\t\t*renderWidth = FrameWidth;\n\t\t*renderHeight = FrameHeight;\n\t}\n}',
#   'graph_idx': 351293,
#   'vul': 0,
#   'id': 1772},
#  {'cve': 'CVE-2022-21732',
#   'cwe_list': ['CWE-770'],
#   'repo_name': 'tensorflow',
#   'commit_hash': 'e3749a6d5d1e8d11806d4a2e9cc3123d1a90b75e',
#   'git_url': 'https://github.com/tensorflow/tensorflow/commit/e3749a6d5d1e8d11806d4a2e9cc3123d1a90b75e',
#   'func': 'void PrivateThreadPoolDatasetOp::MakeDatasetFromOptions(OpKernelContext* ctx,\n                                                        DatasetBase* input,\n                                                        int32_t num_threads,\n                                                        DatasetBase** output) {\n  OP_REQUIRES(ctx, num_threads >= 0,\n              errors::InvalidArgument("`num_threads` must be >= 0"));\n  *output = new Dataset(ctx,\n                        DatasetContext(DatasetContext::Params(\n                            {PrivateThreadPoolDatasetOp::kDatasetType,\n                             PrivateThreadPoolDatasetOp::kDatasetOp})),\n                        input, num_threads);\n}',
#   'graph_idx': 354383,
#   'vul': 1,
#   'id': 5390},
#  {'cve': 'CVE-2022-33747',
#   'cwe_list': ['CWE-400'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '7c3bbd940dd8aeb1649734e5055798cc6f3fea4e',
#   'git_url': 'https://github.com/xen-project/xen/commit/7c3bbd940dd8aeb1649734e5055798cc6f3fea4e',
#   'func': 'int libxl__arch_domain_create(libxl__gc *gc,\n                              libxl_domain_config *d_config,\n                              libxl__domain_build_state *state,\n                              uint32_t domid)\n{\n    libxl_ctx *ctx = libxl__gc_owner(gc);\n    unsigned int shadow_mb = DIV_ROUNDUP(d_config->b_info.shadow_memkb, 1024);\n\n    int r = xc_shadow_control(ctx->xch, domid,\n                              XEN_DOMCTL_SHADOW_OP_SET_ALLOCATION,\n                              &shadow_mb, 0);\n    if (r) {\n        LOGED(ERROR, domid,\n              "Failed to set %u MiB shadow allocation", shadow_mb);\n        return ERROR_FAIL;\n    }\n\n    return 0;\n}',
#   'graph_idx': 401652,
#   'vul': 1,
#   'id': 25506},
#  {'cve': 'CVE-2018-7541',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '9d2f8f9c65d4da35437f50ed9e812a2c5ab313e2',
#   'git_url': 'https://github.com/xen-project/xen/commit/9d2f8f9c65d4da35437f50ed9e812a2c5ab313e2',
#   'func': 'static int gnttab_copy_lock_domains(const struct gnttab_copy *op,\n                                    struct gnttab_copy_buf *src,\n                                    struct gnttab_copy_buf *dest)\n{\n    int rc;\n\n    rc = gnttab_copy_lock_domain(op->source.domid,\n                                 op->flags & GNTCOPY_source_gref, src);\n    if ( rc < 0 )\n        goto error;\n    rc = gnttab_copy_lock_domain(op->dest.domid,\n                                 op->flags & GNTCOPY_dest_gref, dest);\n    if ( rc < 0 )\n        goto error;\n\n    rc = xsm_grant_copy(XSM_HOOK, src->domain, dest->domain);\n    if ( rc < 0 )\n    {\n        rc = GNTST_permission_denied;\n        goto error;\n    }\n    return 0;\n\n error:\n    gnttab_copy_unlock_domains(src, dest);\n    return rc;\n}',
#   'graph_idx': 211472,
#   'vul': 0,
#   'id': 9680},
#  {'cve': 'CVE-2014-9773',
#   'cwe_list': ['CWE-284'],
#   'repo_name': 'atheme',
#   'commit_hash': 'c597156adc60a45b5f827793cd420945f47bc03b',
#   'git_url': 'https://github.com/atheme/atheme/commit/c597156adc60a45b5f827793cd420945f47bc03b',
#   'func': 'void _moddeinit(module_unload_intent_t intent)\n{\n\tservice_named_unbind_command("chanserv", &cs_flags);\n}',
#   'graph_idx': 128890,
#   'vul': 1,
#   'id': 8722},
#  {'cve': 'CVE-2017-6903',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'JACoders/OpenJK',
#   'commit_hash': '8956a35e7b91c4a0dd1fa6db1d28c7f0efbab2d7',
#   'git_url': 'https://github.com/JACoders/OpenJK/commit/8956a35e7b91c4a0dd1fa6db1d28c7f0efbab2d7',
#   'func': 'char **FS_ListFiles( const char *path, const char *extension, int *numfiles ) {\n\treturn FS_ListFilteredFiles( path, extension, NULL, numfiles );\n}',
#   'graph_idx': 165358,
#   'vul': 0,
#   'id': 33206},
#  {'cve': 'CVE-2019-18391',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'virglrenderer',
#   'commit_hash': '2abeb1802e3c005b17a7123e382171b3fb665971',
#   'git_url': 'https://cgit.freedesktop.org/virglrenderer/commit/?id=2abeb1802e3c005b17a7123e382171b3fb665971',
#   'func': 'void vrend_print_context_name(struct vrend_context *ctx)\n{\n   if (ctx)\n      vrend_printf("%s: ", ctx->debug_name);\n   else\n      vrend_printf("HOST: ");\n}',
#   'graph_idx': 278439,
#   'vul': 0,
#   'id': 9411},
#  {'cve': 'CVE-2017-5473',
#   'cwe_list': ['CWE-352'],
#   'repo_name': 'ntop/ntopng',
#   'commit_hash': 'f91fbe3d94c8346884271838ae3406ae633f6f15',
#   'git_url': 'https://github.com/ntop/ntopng/commit/f91fbe3d94c8346884271838ae3406ae633f6f15',
#   'func': 'void lua_push_int_table_entry(lua_State *L, const char *key, u_int64_t value) {\n  if(L) {\n    lua_pushstring(L, key);\n    /* using LUA_NUMBER (double: 64 bit) in place of LUA_INTEGER (ptrdiff_t: 32 or 64 bit\n     * according to the platform, as defined in luaconf.h) to handle big counters */\n    lua_pushnumber(L, (lua_Number)value);\n    lua_settable(L, -3);\n  }\n}',
#   'graph_idx': 156664,
#   'vul': 0,
#   'id': 2179},
#  {'cve': 'CVE-2017-7865',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'FFmpeg',
#   'commit_hash': '2080bc33717955a0e4268e738acf8c1eeddbf8cb',
#   'git_url': 'https://github.com/FFmpeg/FFmpeg/commit/2080bc33717955a0e4268e738acf8c1eeddbf8cb',
#   'func': 'int avcodec_encode_subtitle(AVCodecContext *avctx, uint8_t *buf, int buf_size,\n                            const AVSubtitle *sub)\n{\n    int ret;\n    if (sub->start_display_time) {\n        av_log(avctx, AV_LOG_ERROR, "start_display_time must be 0.\\n");\n        return -1;\n    }\n\n    ret = avctx->codec->encode_sub(avctx, buf, buf_size, sub);\n    avctx->frame_number++;\n    return ret;\n}',
#   'graph_idx': 174265,
#   'vul': 0,
#   'id': 24669},
#  {'cve': 'CVE-2022-4127',
#   'cwe_list': ['CWE-476'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'd785a773bed966a75ca1f11d108ae1897189975b',
#   'git_url': 'https://github.com/torvalds/linux/commit/d785a773bed966a75ca1f11d108ae1897189975b',
#   'func': 'static __poll_t io_poll_parse_events(const struct io_uring_sqe *sqe,\n\t\t\t\t     unsigned int flags)\n{\n\tu32 events;\n\n\tevents = READ_ONCE(sqe->poll32_events);\n#ifdef __BIG_ENDIAN\n\tevents = swahw32(events);\n#endif\n\tif (!(flags & IORING_POLL_ADD_MULTI))\n\t\tevents |= EPOLLONESHOT;\n\treturn demangle_poll(events) | (events & (EPOLLEXCLUSIVE|EPOLLONESHOT));\n}',
#   'graph_idx': 413660,
#   'vul': 0,
#   'id': 798},
#  {'cve': 'CVE-2019-11487',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '15fab63e1e57be9fdb5eec1bbc5916e9825e9acb',
#   'git_url': 'https://git.kernel.org/cgit/linux/kernel/git/torvalds/linux.git/commit/?id=15fab63e1e57be9fdb5eec1bbc5916e9825e9acb',
#   'func': 'static struct fuse_req *__fuse_request_alloc(unsigned npages, gfp_t flags)\n{\n\tstruct fuse_req *req = kmem_cache_zalloc(fuse_req_cachep, flags);\n\tif (req) {\n\t\tstruct page **pages = NULL;\n\t\tstruct fuse_page_desc *page_descs = NULL;\n\n\t\tWARN_ON(npages > FUSE_MAX_MAX_PAGES);\n\t\tif (npages > FUSE_REQ_INLINE_PAGES) {\n\t\t\tpages = fuse_req_pages_alloc(npages, flags,\n\t\t\t\t\t\t     &page_descs);\n\t\t\tif (!pages) {\n\t\t\t\tkmem_cache_free(fuse_req_cachep, req);\n\t\t\t\treturn NULL;\n\t\t\t}\n\t\t} else if (npages) {\n\t\t\tpages = req->inline_pages;\n\t\t\tpage_descs = req->inline_page_descs;\n\t\t}\n\n\t\tfuse_request_init(req, pages, page_descs, npages);\n\t}\n\treturn req;\n}',
#   'graph_idx': 249143,
#   'vul': 0,
#   'id': 32871},
#  {'cve': 'CVE-2022-43945',
#   'cwe_list': ['CWE-770'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'f90497a16e434c2211c66e3de8e77b17868382b8',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=f90497a16e434c2211c66e3de8e77b17868382b8',
#   'func': 'static __be32\nnfsd4_decode_readdir(struct nfsd4_compoundargs *argp, struct nfsd4_readdir *readdir)\n{\n\t__be32 status;\n\n\tif (xdr_stream_decode_u64(argp->xdr, &readdir->rd_cookie) < 0)\n\t\treturn nfserr_bad_xdr;\n\tstatus = nfsd4_decode_verifier4(argp, &readdir->rd_verf);\n\tif (status)\n\t\treturn status;\n\tif (xdr_stream_decode_u32(argp->xdr, &readdir->rd_dircount) < 0)\n\t\treturn nfserr_bad_xdr;\n\tif (xdr_stream_decode_u32(argp->xdr, &readdir->rd_maxcount) < 0)\n\t\treturn nfserr_bad_xdr;\n\tif (xdr_stream_decode_uint32_array(argp->xdr, readdir->rd_bmval,\n\t\t\t\t\t   ARRAY_SIZE(readdir->rd_bmval)) < 0)\n\t\treturn nfserr_bad_xdr;\n\n\treturn nfs_ok;\n}',
#   'graph_idx': 410908,
#   'vul': 1,
#   'id': 19531},
#  {'cve': 'CVE-2018-11357',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'wireshark',
#   'commit_hash': 'ab8a33ef083b9732c89117747a83a905a676faf6',
#   'git_url': 'https://github.com/wireshark/wireshark/commit/ab8a33ef083b9732c89117747a83a905a676faf6',
#   'func': 'gint\ntvb_strneql(tvbuff_t *tvb, const gint offset, const gchar *str, const size_t size)\n{\n\tconst guint8 *ptr;\n\n\tptr = ensure_contiguous_no_exception(tvb, offset, (gint)size, NULL);\n\n\tif (ptr) {\n\t\tint cmp = strncmp((const char *)ptr, str, size);\n\n\t\t/*\n\t\t * Return 0 if equal, -1 otherwise.\n\t\t */\n\t\treturn (cmp == 0 ? 0 : -1);\n\t} else {\n\t\t/*\n\t\t * Not enough characters in the tvbuff to match the\n\t\t * string.\n\t\t */\n\t\treturn -1;\n\t}\n}',
#   'graph_idx': 218722,
#   'vul': 0,
#   'id': 35299},
#  {'cve': 'CVE-2019-1563',
#   'cwe_list': ['CWE-327', 'CWE-203'],
#   'repo_name': 'openssl',
#   'commit_hash': '08229ad838c50f644d7e928e2eef147b4308ad64',
#   'git_url': 'https://git.openssl.org/gitweb/?p=openssl.git;a=commit;h=08229ad838c50f644d7e928e2eef147b4308ad64',
#   'func': 'int CMS_decrypt(CMS_ContentInfo *cms, EVP_PKEY *pk, X509 *cert,\n                BIO *dcont, BIO *out, unsigned int flags)\n{\n    int r;\n    BIO *cont;\n    if (OBJ_obj2nid(CMS_get0_type(cms)) != NID_pkcs7_enveloped) {\n        CMSerr(CMS_F_CMS_DECRYPT, CMS_R_TYPE_NOT_ENVELOPED_DATA);\n        return 0;\n    }\n    if (!dcont && !check_content(cms))\n        return 0;\n    if (flags & CMS_DEBUG_DECRYPT)\n        cms->d.envelopedData->encryptedContentInfo->debug = 1;\n    else\n        cms->d.envelopedData->encryptedContentInfo->debug = 0;\n    if (!pk && !cert && !dcont && !out)\n        return 1;\n    if (pk && !CMS_decrypt_set1_pkey(cms, pk, cert))\n        return 0;\n    cont = CMS_dataInit(cms, dcont);\n    if (!cont)\n        return 0;\n    r = cms_copy_content(out, cont, flags);\n    do_free_upto(cont, dcont);\n    return r;\n}',
#   'graph_idx': 262771,
#   'vul': 1,
#   'id': 7534},
#  {'cve': 'CVE-2021-3798',
#   'cwe_list': ['CWE-200'],
#   'repo_name': 'opencryptoki',
#   'commit_hash': '4e3b43c3d8844402c04a66b55c6c940f965109f0',
#   'git_url': 'https://github.com/opencryptoki/opencryptoki/commit/4e3b43c3d8844402c04a66b55c6c940f965109f0',
#   'func': 'CK_RV token_specific_final(STDLL_TokData_t *tokdata,\n                           CK_BBOOL token_specific_final)\n{\n    UNUSED(tokdata);\n    UNUSED(token_specific_final);\n\n    TRACE_INFO("soft %s running\\n", __func__);\n\n    return CKR_OK;\n}',
#   'graph_idx': 389137,
#   'vul': 0,
#   'id': 29566},
#  {'cve': 'CVE-2009-0322',
#   'cwe_list': ['CWE-399', 'CWE-189'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '81156928f8fe31621e467490b9d441c0285998c3',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/stable/linux.git;a=commit;h=81156928f8fe31621e467490b9d441c0285998c3',
#   'func': 'static ssize_t read_rbu_image_type(struct kobject *kobj,\n\t\t\t\t   struct bin_attribute *bin_attr,\n\t\t\t\t   char *buffer, loff_t pos, size_t count)\n{\n\tint size = 0;\n\tif (!pos)\n\t\tsize = sprintf(buffer, "%s\\n", image_type);\n\treturn size;\n}',
#   'graph_idx': 2637,
#   'vul': 1,
#   'id': 25565},
#  {'cve': 'CVE-2022-3595',
#   'cwe_list': ['CWE-415'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'b854b4ee66437e6e1622fda90529c814978cb4ca',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/stable/linux.git/commit/?id=b854b4ee66437e6e1622fda90529c814978cb4ca',
#   'func': 'static void\nsess_free_buffer(struct sess_data *sess_data)\n{\n\tint i;\n\n\t/* zero the session data before freeing, as it might contain sensitive info (keys, etc) */\n\tfor (i = 0; i < 3; i++)\n\t\tif (sess_data->iov[i].iov_base)\n\t\t\tmemzero_explicit(sess_data->iov[i].iov_base, sess_data->iov[i].iov_len);\n\n\tfree_rsp_buf(sess_data->buf0_type, sess_data->iov[0].iov_base);\n\tsess_data->buf0_type = CIFS_NO_BUFFER;\n\tkfree(sess_data->iov[2].iov_base);\n}',
#   'graph_idx': 404981,
#   'vul': 1,
#   'id': 35591},
#  {'cve': 'CVE-2016-10905',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '36e4ad0316c017d5b271378ed9a1c9a4b77fab5f',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=36e4ad0316c017d5b271378ed9a1c9a4b77fab5f',
#   'func': 'void gfs2_clear_rgrpd(struct gfs2_sbd *sdp)\n{\n\tstruct rb_node *n;\n\tstruct gfs2_rgrpd *rgd;\n\tstruct gfs2_glock *gl;\n\n\twhile ((n = rb_first(&sdp->sd_rindex_tree))) {\n\t\trgd = rb_entry(n, struct gfs2_rgrpd, rd_node);\n\t\tgl = rgd->rd_gl;\n\n\t\trb_erase(n, &sdp->sd_rindex_tree);\n\n\t\tif (gl) {\n\t\t\tspin_lock(&gl->gl_lockref.lock);\n\t\t\tgl->gl_object = NULL;\n\t\t\tspin_unlock(&gl->gl_lockref.lock);\n\t\t\tgfs2_glock_add_to_lru(gl);\n\t\t\tgfs2_glock_put(gl);\n\t\t}\n\n\t\tgfs2_free_clones(rgd);\n\t\tkfree(rgd->rd_bits);\n\t\treturn_all_reservations(rgd);\n\t\tkmem_cache_free(gfs2_rgrpd_cachep, rgd);\n\t}\n}',
#   'graph_idx': 258762,
#   'vul': 1,
#   'id': 3624},
#  {'cve': 'CVE-2022-1809',
#   'cwe_list': ['CWE-824'],
#   'repo_name': 'radareorg/radare2',
#   'commit_hash': '919e3ac1a13f753c73e7a8e8d8bb4a143218732d',
#   'git_url': 'https://github.com/radareorg/radare2/commit/919e3ac1a13f753c73e7a8e8d8bb4a143218732d',
#   'func': 'static bool vtable_is_value_in_text_section(RVTableContext *context, ut64 curAddress, ut64 *value) {\n\t//value at the current address\n\tut64 curAddressValue;\n\tif (!context->read_addr (context->anal, curAddress, &curAddressValue)) {\n\t\treturn false;\n\t}\n\t//if the value is in text section\n\tbool ret = vtable_addr_in_text_section (context, curAddressValue);\n\tif (value) {\n\t\t*value = curAddressValue;\n\t}\n\treturn ret;\n}',
#   'graph_idx': 377071,
#   'vul': 1,
#   'id': 15052},
#  {'cve': 'CVE-2014-7935',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': '8880b279a491ca69db564a975cce3bbfd8f5c3e3',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/8880b279a491ca69db564a975cce3bbfd8f5c3e3',
#   'func': 'void TtsMessageFilter::OnChannelClosingInUIThread() {\n  CHECK(BrowserThread::CurrentlyOn(BrowserThread::UI));\n  TtsController::GetInstance()->RemoveVoicesChangedDelegate(this);\n\n  weak_ptr_factory_.InvalidateWeakPtrs();\n  Release();  // Balanced in TtsMessageFilter().\n}',
#   'graph_idx': 83803,
#   'vul': 1,
#   'id': 34473},
#  {'cve': 'CVE-2017-9228',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'kkos/oniguruma',
#   'commit_hash': '3b63d12038c8d8fc278e81c942fa9bec7c704c8b',
#   'git_url': 'https://github.com/kkos/oniguruma/commit/3b63d12038c8d8fc278e81c942fa9bec7c704c8b',
#   'func': 'static int\nnext_state_class(CClassNode* cc, OnigCodePoint* vs, enum CCVALTYPE* type,\n\t\t enum CCSTATE* state, ScanEnv* env)\n{\n  int r;\n\n  if (*state == CCS_RANGE)\n    return ONIGERR_CHAR_CLASS_VALUE_AT_END_OF_RANGE;\n\n  if (*state == CCS_VALUE && *type != CCV_CLASS) {\n    if (*type == CCV_SB)\n      BITSET_SET_BIT(cc->bs, (int )(*vs));\n    else if (*type == CCV_CODE_POINT) {\n      r = add_code_range(&(cc->mbuf), env, *vs, *vs);\n      if (r < 0) return r;\n    }\n  }\n\n  *state = CCS_VALUE;\n  *type  = CCV_CLASS;\n  return 0;\n}',
#   'graph_idx': 180942,
#   'vul': 1,
#   'id': 22192},
#  {'cve': 'CVE-2019-18424',
#   'cwe_list': ['CWE-78'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': '319f9a0ba94c7db505cd5dd9cb0b037ab1aa8e12',
#   'git_url': 'https://github.com/xen-project/xen/commit/319f9a0ba94c7db505cd5dd9cb0b037ab1aa8e12',
#   'func': 'static void pcidev_struct_fill(libxl_device_pci *pcidev, unsigned int domain,\n                               unsigned int bus, unsigned int dev,\n                               unsigned int func, unsigned int vdevfn)\n{\n    pcidev->domain = domain;\n    pcidev->bus = bus;\n    pcidev->dev = dev;\n    pcidev->func = func;\n    pcidev->vdevfn = vdevfn;\n}',
#   'graph_idx': 269077,
#   'vul': 0,
#   'id': 28457},
#  {'cve': 'CVE-2022-1735',
#   'cwe_list': ['CWE-120'],
#   'repo_name': 'vim',
#   'commit_hash': '7ce5b2b590256ce53d6af28c1d203fb3bc1d2d97',
#   'git_url': 'https://github.com/vim/vim/commit/7ce5b2b590256ce53d6af28c1d203fb3bc1d2d97',
#   'func': 'void\ndeleted_lines(linenr_T lnum, long count)\n{\n    changed_lines(lnum, 0, lnum + count, -count);\n}',
#   'graph_idx': 376306,
#   'vul': 0,
#   'id': 13080},
#  {'cve': 'CVE-2010-4254',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'mono',
#   'commit_hash': '65292a69c837b8a5f7a392d34db63de592153358',
#   'git_url': 'https://github.com/mono/mono/commit/65292a69c837b8a5f7a392d34db63de592153358',
#   'func': 'MonoBoolean\nmono_declsec_get_method_action (MonoMethod *method, guint32 action, MonoDeclSecurityEntry *entry)\n{\n\tif (method->flags & METHOD_ATTRIBUTE_HAS_SECURITY) {\n\t\tguint32 idx = mono_method_get_index (method);\n\t\tidx <<= MONO_HAS_DECL_SECURITY_BITS;\n\t\tidx |= MONO_HAS_DECL_SECURITY_METHODDEF;\n\t\treturn get_declsec_action (method->klass->image, idx, action, entry);\n\t}\n\treturn FALSE;\n}',
#   'graph_idx': 17576,
#   'vul': 0,
#   'id': 36017},
#  {'cve': 'CVE-2019-20096',
#   'cwe_list': ['CWE-401'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '1d3ff0950e2b40dc861b1739029649d03f591820',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=1d3ff0950e2b40dc861b1739029649d03f591820',
#   'func': 'int dccp_feat_register_sp(struct sock *sk, u8 feat, u8 is_local,\n\t\t\t  u8 const *list, u8 len)\n{\t /* any changes must be registered before establishing the connection */\n\tif (sk->sk_state != DCCP_CLOSED)\n\t\treturn -EISCONN;\n\tif (dccp_feat_type(feat) != FEAT_SP)\n\t\treturn -EINVAL;\n\treturn __feat_register_sp(&dccp_sk(sk)->dccps_featneg, feat, is_local,\n\t\t\t\t  0, list, len);\n}',
#   'graph_idx': 279999,
#   'vul': 0,
#   'id': 2882},
#  {'cve': 'CVE-2012-0056',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'e268337dfe26dfc7efd422a804dbb27977a3cccc',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commitdiff;h=e268337dfe26dfc7efd422a804dbb27977a3cccc',
#   'func': 'static int proc_pid_auxv(struct task_struct *task, char *buffer)\n{\n\tstruct mm_struct *mm = mm_for_maps(task);\n\tint res = PTR_ERR(mm);\n\tif (mm && !IS_ERR(mm)) {\n\t\tunsigned int nwords = 0;\n\t\tdo {\n\t\t\tnwords += 2;\n\t\t} while (mm->saved_auxv[nwords - 2] != 0); /* AT_NULL */\n\t\tres = nwords * sizeof(mm->saved_auxv[0]);\n\t\tif (res > PAGE_SIZE)\n\t\t\tres = PAGE_SIZE;\n\t\tmemcpy(buffer, mm->saved_auxv, res);\n\t\tmmput(mm);\n\t}\n\treturn res;\n}',
#   'graph_idx': 24183,
#   'vul': 0,
#   'id': 13366},
#  {'cve': 'CVE-2014-3154',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'chromium',
#   'commit_hash': 'f14efc560a12a513696d6396413b138879dabd7a',
#   'git_url': 'https://github.com/chromium/chromium/commit/f14efc560a12a513696d6396413b138879dabd7a',
#   'func': 'void ChildThread::Shutdown() {\n  // Delete objects that hold references to blink so derived classes can\n  // safely shutdown blink in their Shutdown implementation.\n  file_system_dispatcher_.reset();\n  quota_dispatcher_.reset();\n}',
#   'graph_idx': 68580,
#   'vul': 1,
#   'id': 25964},
#  {'cve': 'CVE-2012-2674',
#   'cwe_list': ['CWE-189'],
#   'repo_name': 'android/platform_bionic',
#   'commit_hash': '7f5aa4f35e23fd37425b3a5041737cdf58f87385',
#   'git_url': 'https://github.com/android/platform_bionic/commit/7f5aa4f35e23fd37425b3a5041737cdf58f87385',
#   'func': "void* leak_malloc(size_t bytes)\n{\n    // allocate enough space infront of the allocation to store the pointer for\n    // the alloc structure. This will making free'ing the structer really fast!\n\n    // 1. allocate enough memory and include our header\n    // 2. set the base pointer to be right after our header\n\n    void* base = dlmalloc(bytes + sizeof(AllocationEntry));\n    if (base != NULL) {\n        pthread_mutex_lock(&gAllocationsMutex);\n\n            intptr_t backtrace[BACKTRACE_SIZE];\n            size_t numEntries = get_backtrace(backtrace, BACKTRACE_SIZE);\n\n            AllocationEntry* header = (AllocationEntry*)base;\n            header->entry = record_backtrace(backtrace, numEntries, bytes);\n            header->guard = GUARD;\n\n            // now increment base to point to after our header.\n            // this should just work since our header is 8 bytes.\n            base = (AllocationEntry*)base + 1;\n\n        pthread_mutex_unlock(&gAllocationsMutex);\n    }\n\n    return base;\n}",
#   'graph_idx': 33442,
#   'vul': 1,
#   'id': 35481},
#  {'cve': 'CVE-2019-19274',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'python/cpython',
#   'commit_hash': 'dcfcd146f8e6fc5c2fc16a4c192a0c5f5ca8c53c',
#   'git_url': 'https://github.com/python/cpython/commit/dcfcd146f8e6fc5c2fc16a4c192a0c5f5ca8c53c',
#   'func': 'static int PARSER_FLAGS(PyCompilerFlags *flags)\n{\n    int parser_flags = 0;\n    if (!flags)\n        return 0;\n    if (flags->cf_flags & PyCF_DONT_IMPLY_DEDENT)\n        parser_flags |= PyPARSE_DONT_IMPLY_DEDENT;\n    if (flags->cf_flags & PyCF_IGNORE_COOKIE)\n        parser_flags |= PyPARSE_IGNORE_COOKIE;\n    if (flags->cf_flags & CO_FUTURE_BARRY_AS_BDFL)\n        parser_flags |= PyPARSE_BARRY_AS_BDFL;\n    return parser_flags;\n}',
#   'graph_idx': 273778,
#   'vul': 1,
#   'id': 30716},
#  {'cve': 'CVE-2022-47942',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '8f0541186e9ad1b62accc9519cc2b7a7240272a7',
#   'git_url': 'https://github.com/torvalds/linux/commit/8f0541186e9ad1b62accc9519cc2b7a7240272a7',
#   'func': 'int ksmbd_vfs_zero_data(struct ksmbd_work *work, struct ksmbd_file *fp,\n\t\t\tloff_t off, loff_t len)\n{\n\tsmb_break_all_levII_oplock(work, fp, 1);\n\tif (fp->f_ci->m_fattr & FILE_ATTRIBUTE_SPARSE_FILE_LE)\n\t\treturn vfs_fallocate(fp->filp,\n\t\t\t\t     FALLOC_FL_PUNCH_HOLE | FALLOC_FL_KEEP_SIZE,\n\t\t\t\t     off, len);\n\n\treturn vfs_fallocate(fp->filp,\n\t\t\t     FALLOC_FL_ZERO_RANGE | FALLOC_FL_KEEP_SIZE,\n\t\t\t     off, len);\n}',
#   'graph_idx': 416730,
#   'vul': 0,
#   'id': 28504},
#  {'cve': 'CVE-2009-2691',
#   'cwe_list': ['CWE-200'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '00f89d218523b9bf6b522349c039d5ac80aa536d',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=00f89d218523b9bf6b522349c039d5ac80aa536d',
#   'func': 'struct mm_struct *mm_for_maps(struct task_struct *task)\n{\n\tstruct mm_struct *mm = get_task_mm(task);\n\tif (!mm)\n\t\treturn NULL;\n\tif (mm != current->mm) {\n\t\t/*\n\t\t * task->mm can be changed before security check,\n\t\t * in that case we must notice the change after.\n\t\t */\n\t\tif (!ptrace_may_access(task, PTRACE_MODE_READ) ||\n\t\t    mm != task->mm) {\n\t\t\tmmput(mm);\n\t\t\treturn NULL;\n\t\t}\n\t}\n\tdown_read(&mm->mmap_sem);\n\treturn mm;\n}',
#   'graph_idx': 4618,
#   'vul': 1,
#   'id': 4886},
#  {'cve': 'CVE-2016-5165',
#   'cwe_list': ['CWE-79'],
#   'repo_name': 'chromium',
#   'commit_hash': 'd5e6098dc2e984befc836f482845137245fa04e2',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/d5e6098dc2e984befc836f482845137245fa04e2',
#   'func': 'void DevToolsWindow::InspectElement(\n    content::RenderFrameHost* inspected_frame_host,\n    int x,\n    int y) {\n  scoped_refptr<DevToolsAgentHost> agent(\n      DevToolsAgentHost::GetOrCreateFor(inspected_frame_host));\n  bool should_measure_time = FindDevToolsWindow(agent.get()) == NULL;\n  base::TimeTicks start_time = base::TimeTicks::Now();\n  // TODO(loislo): we should initiate DevTools window opening from within\n  // renderer. Otherwise, we still can hit a race condition here.\n  if (agent->GetType() == content::DevToolsAgentHost::TYPE_WEB_CONTENTS) {\n    OpenDevToolsWindow(agent->GetWebContents());\n  } else {\n    OpenDevToolsWindow(Profile::FromBrowserContext(agent->GetBrowserContext()),\n                       agent);\n  }\n  DevToolsWindow* window = FindDevToolsWindow(agent.get());\n  if (window) {\n    agent->InspectElement(window->bindings_, x, y);\n    if (should_measure_time)\n      window->inspect_element_start_time_ = start_time;\n  }\n}',
#   'graph_idx': 144414,
#   'vul': 0,
#   'id': 9515},
#  {'cve': 'CVE-2020-29660',
#   'cwe_list': ['CWE-667', 'CWE-416'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'c8bcd9c5be24fb9e6132e97da5a35e55a83e36b9',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=c8bcd9c5be24fb9e6132e97da5a35e55a83e36b9',
#   'func': 'static void tty_device_create_release(struct device *dev)\n{\n\tdev_dbg(dev, "releasing...\\n");\n\tkfree(dev);\n}',
#   'graph_idx': 307612,
#   'vul': 0,
#   'id': 17355},
#  {'cve': 'CVE-2019-1547',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'openssl',
#   'commit_hash': '7c1709c2da5414f5b6133d00a03fc8c5bf996c7a',
#   'git_url': 'https://git.openssl.org/gitweb/?p=openssl.git;a=commit;h=7c1709c2da5414f5b6133d00a03fc8c5bf996c7a',
#   'func': 'BN_MONT_CTX *EC_GROUP_get_mont_data(const EC_GROUP *group)\n{\n    return group->mont_data;\n}',
#   'graph_idx': 262486,
#   'vul': 0,
#   'id': 26911},
#  {'cve': 'CVE-2021-40564',
#   'cwe_list': ['CWE-476'],
#   'repo_name': 'gpac',
#   'commit_hash': 'cf6771c857eb9a290e2c19ddacfdd3ed98b27618',
#   'git_url': 'https://github.com/gpac/gpac/commit/cf6771c857eb9a290e2c19ddacfdd3ed98b27618',
#   'func': 'static int calc_min_log2_tile_cols(int Sb64Cols) {\n\tint minLog2 = 0;\n\twhile ((VP9_MAX_TILE_WIDTH_B64 << minLog2) < Sb64Cols)\n\t\tminLog2++;\n\n\treturn minLog2;\n}',
#   'graph_idx': 349297,
#   'vul': 0,
#   'id': 12885},
#  {'cve': 'CVE-2021-45930',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'qt/qtsvg',
#   'commit_hash': '79bb9f51fa374106a612d17c9d98d35d807be670',
#   'git_url': 'https://github.com/qt/qtsvg/commit/79bb9f51fa374106a612d17c9d98d35d807be670',
#   'func': 'bool QSvgHandler::inStyle() const\n{\n    return m_inStyle;\n}',
#   'graph_idx': 347751,
#   'vul': 0,
#   'id': 2685},
#  {'cve': 'CVE-2021-3623',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'stefanberger/libtpms',
#   'commit_hash': '2e6173c',
#   'git_url': 'https://github.com/stefanberger/libtpms/commit/2e6173c',
#   'func': 'TPM_RC\nTPMI_RH_HIERARCHY_AUTH_Unmarshal(TPMI_RH_HIERARCHY_AUTH *target, BYTE **buffer, INT32 *size)\n{\n    TPM_RC rc = TPM_RC_SUCCESS;\n    \n    if (rc == TPM_RC_SUCCESS) {\n\trc = TPM_HANDLE_Unmarshal(target, buffer, size);  \n    }\n    if (rc == TPM_RC_SUCCESS) {\n\tswitch (*target) {\n\t  case TPM_RH_OWNER:\n\t  case TPM_RH_PLATFORM:\n\t  case TPM_RH_ENDORSEMENT:\n\t  case TPM_RH_LOCKOUT:\n\t    break;\n\t  default:\n\t    rc = TPM_RC_VALUE;\n\t}\n    }\n    return rc;\n}',
#   'graph_idx': 362878,
#   'vul': 1,
#   'id': 4097},
#  {'cve': 'CVE-2020-11049',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'FreeRDP',
#   'commit_hash': 'c367f65d42e0d2e1ca248998175180aa9c2eacd0',
#   'git_url': 'https://github.com/FreeRDP/FreeRDP/commit/c367f65d42e0d2e1ca248998175180aa9c2eacd0',
#   'func': 'static HANDLE freerdp_peer_get_event_handle(freerdp_peer* client)\n{\n\tHANDLE hEvent = NULL;\n\trdpTransport* transport = client->context->rdp->transport;\n\tBIO_get_event(transport->frontBio, &hEvent);\n\treturn hEvent;\n}',
#   'graph_idx': 289575,
#   'vul': 0,
#   'id': 8568},
#  {'cve': 'CVE-2022-29859',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'ambiot/amb1_sdk',
#   'commit_hash': '4b73f58f32914d0081d79a79e53a3215c8c1ea56',
#   'git_url': 'https://github.com/ambiot/amb1_sdk/commit/4b73f58f32914d0081d79a79e53a3215c8c1ea56',
# ...
#   'repo_name': 'xen-project/xen',
#   'commit_hash': 'fe21b78ef99a1b505cfb6d3789ede9591609dd70',
#   'git_url': 'https://github.com/xen-project/xen/commit/fe21b78ef99a1b505cfb6d3789ede9591609dd70',
#   'func': 'bool_t p2m_switch_vcpu_altp2m_by_id(struct vcpu *v, unsigned int idx)\n{\n    struct domain *d = v->domain;\n    bool_t rc = 0;\n\n    if ( idx >= MAX_ALTP2M )\n        return rc;\n\n    altp2m_list_lock(d);\n\n    if ( d->arch.altp2m_eptp[idx] != mfn_x(INVALID_MFN) )\n    {\n        if ( idx != vcpu_altp2m(v).p2midx )\n        {\n            atomic_dec(&p2m_get_altp2m(v)->active_vcpus);\n            vcpu_altp2m(v).p2midx = idx;\n            atomic_inc(&p2m_get_altp2m(v)->active_vcpus);\n            altp2m_vcpu_update_p2m(v);\n        }\n        rc = 1;\n    }\n\n    altp2m_list_unlock(d);\n    return rc;\n}',
#   'graph_idx': 266062,
#   'vul': 0,
#   'id': 28778},
#  {'cve': 'CVE-2022-47942',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '8f0541186e9ad1b62accc9519cc2b7a7240272a7',
#   'git_url': 'https://github.com/torvalds/linux/commit/8f0541186e9ad1b62accc9519cc2b7a7240272a7',
#   'func': 'static void lock_dir(struct ksmbd_file *dir_fp)\n{\n\tstruct dentry *dir = dir_fp->filp->f_path.dentry;\n\n\tinode_lock_nested(d_inode(dir), I_MUTEX_PARENT);\n}',
#   'graph_idx': 416682,
#   'vul': 0,
#   'id': 10069},
#  {'cve': 'CVE-2018-5344',
#   'cwe_list': ['CWE-416', 'CWE-362'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'ae6650163c66a7eff1acd6eb8b0f752dcfa8eba5',
#   'git_url': 'https://github.com/torvalds/linux/commit/ae6650163c66a7eff1acd6eb8b0f752dcfa8eba5',
#   'func': 'static int xor_init(struct loop_device *lo, const struct loop_info64 *info)\n{\n\tif (unlikely(info->lo_encrypt_key_size <= 0))\n\t\treturn -EINVAL;\n\treturn 0;\n}',
#   'graph_idx': 206856,
#   'vul': 0,
#   'id': 8259},
#  {'cve': 'CVE-2021-32268',
#   'cwe_list': ['CWE-787'],
#   'repo_name': 'gpac',
#   'commit_hash': '388ecce75d05e11fc8496aa4857b91245007d26e',
#   'git_url': 'https://github.com/gpac/gpac/commit/388ecce75d05e11fc8496aa4857b91245007d26e',
#   'func': 'void totl_box_del(GF_Box *s)\n{\n\tgf_free((GF_TRPYBox *)s);\n}',
#   'graph_idx': 340674,
#   'vul': 0,
#   'id': 9986},
#  {'cve': 'CVE-2015-6776',
#   'cwe_list': ['CWE-119'],
#   'repo_name': 'pdfium',
#   'commit_hash': '0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'git_url': 'https://pdfium.googlesource.com/pdfium/+/0300abca7af7ad627ad9b59bdb88c2fec0505b12',
#   'func': 'OPJ_BOOL opj_jp2_end_compress(\topj_jp2_t *jp2,\n\t\t\t\t\t\t\t    opj_stream_private_t *cio,\n\t\t\t\t\t\t\t    opj_event_mgr_t * p_manager\n                                )\n{\n\t/* preconditions */\n\tassert(jp2 != 00);\n\tassert(cio != 00);\n\tassert(p_manager != 00);\n\n\t/* customization of the end encoding */\n\topj_jp2_setup_end_header_writing(jp2);\n\n\tif (! opj_j2k_end_compress(jp2->j2k,cio,p_manager)) {\n\t\treturn OPJ_FALSE;\n\t}\n\n\t/* write header */\n\treturn opj_jp2_exec(jp2,jp2->m_procedure_list,cio,p_manager);\n}',
#   'graph_idx': 101232,
#   'vul': 1,
#   'id': 12331},
#  {'cve': 'CVE-2016-0846',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'android',
#   'commit_hash': 'f3199c228aced7858b75a8070b8358c155ae0149',
#   'git_url': 'https://android.googlesource.com/platform/frameworks/native/+/f3199c228aced7858b75a8070b8358c155ae0149',
#   'func': 'sp<IMemoryHeap> BpMemory::getMemory(ssize_t* offset, size_t* size) const\n{\n    if (mHeap == 0) {\n        Parcel data, reply;\n        data.writeInterfaceToken(IMemory::getInterfaceDescriptor());\n        if (remote()->transact(GET_MEMORY, data, &reply) == NO_ERROR) {\n            sp<IBinder> heap = reply.readStrongBinder();\n            ssize_t o = reply.readInt32();\n            size_t s = reply.readInt32();\n            if (heap != 0) {\n                mHeap = interface_cast<IMemoryHeap>(heap);\n                if (mHeap != 0) {\n                    mOffset = o;\n                    mSize = s;\n                }\n            }\n        }\n    }\n    if (offset) *offset = mOffset;\n    if (size) *size = mSize;\n    return mHeap;\n}',
#   'graph_idx': 111760,
#   'vul': 1,
#   'id': 7974},
#  {'cve': 'CVE-2022-2862',
#   'cwe_list': ['CWE-416'],
#   'repo_name': 'vim',
#   'commit_hash': '1889f499a4f248cd84e0e0bf6d0d820016774494',
#   'git_url': 'https://github.com/vim/vim/commit/1889f499a4f248cd84e0e0bf6d0d820016774494',
#   'func': 'int\nmay_get_next_line(char_u *whitep, char_u **arg, cctx_T *cctx)\n{\n    *arg = skipwhite(whitep);\n    if (vim9_bad_comment(*arg))\n\treturn FAIL;\n    if (**arg == NUL || (VIM_ISWHITE(*whitep) && vim9_comment_start(*arg)))\n    {\n\tchar_u *next = next_line_from_context(cctx, TRUE);\n\n\tif (next == NULL)\n\t    return FAIL;\n\t*arg = skipwhite(next);\n    }\n    return OK;\n}',
#   'graph_idx': 387519,
#   'vul': 0,
#   'id': 9134},
#  {'cve': 'CVE-2016-1636',
#   'cwe_list': ['CWE-264'],
#   'repo_name': 'chromium',
#   'commit_hash': '0979e9712439b056355af462d68fe5c6d9ee5466',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/0979e9712439b056355af462d68fe5c6d9ee5466',
#   'func': 'bool ScriptResource::mimeTypeAllowedByNosniff() const\n{\n    return parseContentTypeOptionsHeader(m_response.httpHeaderField(HTTPNames::X_Content_Type_Options)) != ContentTypeOptionsNosniff || MIMETypeRegistry::isSupportedJavaScriptMIMEType(mimeType());\n}',
#   'graph_idx': 108787,
#   'vul': 0,
#   'id': 33809},
#  {'cve': 'CVE-2009-3623',
#   'cwe_list': ['CWE-287'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '80fc015bdfe1f5b870c1e1ee02d78e709523fee7',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=80fc015bdfe1f5b870c1e1ee02d78e709523fee7',
#   'func': 'void\nnfsd4_cb_recall(struct nfs4_delegation *dp)\n{\n\tstruct nfs4_client *clp = dp->dl_client;\n\tstruct rpc_clnt *clnt = clp->cl_cb_conn.cb_client;\n\tstruct rpc_message msg = {\n\t\t.rpc_proc = &nfs4_cb_procedures[NFSPROC4_CLNT_CB_RECALL],\n\t\t.rpc_argp = dp,\n\t\t.rpc_cred = clp->cl_cb_conn.cb_cred\n\t};\n\tint status;\n\n\tdp->dl_retries = 1;\n\tstatus = rpc_call_async(clnt, &msg, RPC_TASK_SOFT,\n\t\t\t\t&nfsd4_cb_recall_ops, dp);\n\tif (status) {\n\t\tput_nfs4_client(clp);\n\t\tnfs4_put_delegation(dp);\n\t}\n}',
#   'graph_idx': 8802,
#   'vul': 1,
#   'id': 30787},
#  {'cve': 'CVE-2022-36043',
#   'cwe_list': ['CWE-415'],
#   'repo_name': 'rizinorg/rizin',
#   'commit_hash': 'a3d50c1ea185f3f642f2d8180715f82d98840784',
#   'git_url': 'https://github.com/rizinorg/rizin/commit/a3d50c1ea185f3f642f2d8180715f82d98840784',
#   'func': 'static RzList *relocs(RzBinFile *bf) {\n\trz_return_val_if_fail(bf && bf->o, NULL);\n\tQnxObj *qo = bf->o->bin_obj;\n\treturn rz_list_clone(qo->fixups);\n}',
#   'graph_idx': 396113,
#   'vul': 1,
#   'id': 19782},
#  {'cve': 'CVE-2017-9059',
#   'cwe_list': ['CWE-404'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'c70422f760c120480fee4de6c38804c72aa26bc1',
#   'git_url': 'https://github.com/torvalds/linux/commit/c70422f760c120480fee4de6c38804c72aa26bc1',
#   'func': 'static void svc_rdma_release_rqst(struct svc_rqst *rqstp)\n{\n}',
#   'graph_idx': 179524,
#   'vul': 0,
#   'id': 35882},
#  {'cve': 'CVE-2013-0864',
#   'cwe_list': ['CWE-189'],
#   'repo_name': 'ffmpeg',
#   'commit_hash': '9547034f9120187e23ad76424dd4d70247e62212',
#   'git_url': 'http://git.videolan.org/?p=ffmpeg.git;a=commit;h=9547034f9120187e23ad76424dd4d70247e62212',
#   'func': 'static void gif_copy_img_rect(const uint32_t *src, uint32_t *dst,\n                              int linesize, int l, int t, int w, int h)\n{\n    const int y_start = t * linesize;\n    const uint32_t *src_px, *src_pr,\n                   *src_py = src + y_start,\n                   *dst_py = dst + y_start;\n    const uint32_t *src_pb = src_py + t * linesize;\n    uint32_t *dst_px;\n\n    for (; src_py < src_pb; src_py += linesize, dst_py += linesize) {\n        src_px = src_py + l;\n        dst_px = (uint32_t *)dst_py + l;\n        src_pr = src_px + w;\n\n        for (; src_px < src_pr; src_px++, dst_px++)\n            *dst_px = *src_px;\n    }\n}',
#   'graph_idx': 52736,
#   'vul': 1,
#   'id': 17233},
#  {'cve': 'CVE-2022-42311',
#   'cwe_list': ['CWE-770'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': 'f6d00133643a524d2138c9e3f192bbde719050ba',
#   'git_url': 'https://github.com/xen-project/xen/commit/f6d00133643a524d2138c9e3f192bbde719050ba',
#   'func': 'static bool conn_can_read(struct connection *conn)\n{\n\tif (conn->is_ignored)\n\t\treturn false;\n\n\tif (!conn->funcs->can_read(conn))\n\t\treturn false;\n\n\t/*\n\t * For stalled connection, we want to process the pending\n\t * command as soon as live-update has aborted.\n\t */\n\tif (conn->is_stalled)\n\t\treturn !lu_is_pending();\n\n\treturn true;\n}',
#   'graph_idx': 407410,
#   'vul': 0,
#   'id': 25872},
#  {'cve': 'CVE-2018-8791',
#   'cwe_list': ['CWE-125'],
#   'repo_name': 'rdesktop',
#   'commit_hash': '4dca546d04321a610c1835010b5dad85163b65e1',
#   'git_url': 'https://github.com/rdesktop/rdesktop/commit/4dca546d04321a610c1835010b5dad85163b65e1',
#   'func': 'static void\nseamless_process(STREAM s)\n{\n\tunsigned int pkglen;\n\tchar *buf;\n\n\tpkglen = s->end - s->p;\n\t/* str_handle_lines requires null terminated strings */\n\tbuf = xmalloc(pkglen + 1);\n\tSTRNCPY(buf, (char *) s->p, pkglen + 1);\n\tstr_handle_lines(buf, &seamless_rest, seamless_line_handler, NULL);\n\n\txfree(buf);\n}',
#   'graph_idx': 244924,
#   'vul': 1,
#   'id': 8397},
#  {'cve': 'CVE-2016-10164',
#   'cwe_list': ['CWE-787', 'CWE-190', 'CWE-119'],
#   'repo_name': 'xorg/lib/libXpm',
#   'commit_hash': 'd1167418f0fd02a27f617ec5afd6db053afbe185',
#   'git_url': 'https://cgit.freedesktop.org/xorg/lib/libXpm/commit/?id=d1167418f0fd02a27f617ec5afd6db053afbe185',
#   'func': 'static void\nCountExtensions(\n    XpmExtension\t*ext,\n    unsigned int\t num,\n    unsigned int\t*ext_size,\n    unsigned int\t*ext_nlines)\n{\n    unsigned int x, y, a, size, nlines;\n    char **line;\n\n    size = 0;\n    nlines = 0;\n    for (x = 0; x < num; x++, ext++) {\n\t/* 1 for the name */\n\tnlines += ext->nlines + 1;\n\t/* 8 = 7 (for "XPMEXT ") + 1 (for 0) */\n\tsize += strlen(ext->name) + 8;\n\ta = ext->nlines;\n\tfor (y = 0, line = ext->lines; y < a; y++, line++)\n\t    size += strlen(*line) + 1;\n    }\n    /* 10 and 1 are for the ending "XPMENDEXT" */\n    *ext_size = size + 10;\n    *ext_nlines = nlines + 1;\n}',
#   'graph_idx': 158579,
#   'vul': 1,
#   'id': 27231},
#  {'cve': 'CVE-2010-1643',
#   'cwe_list': ['CWE-Other'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': '731572d39fcd3498702eda4600db4c43d51e0b26',
#   'git_url': 'http://git.kernel.org/?p=linux/kernel/git/torvalds/linux.git;a=commit;h=731572d39fcd3498702eda4600db4c43d51e0b26',
#   'func': 'static inline int shmem_acct_size(unsigned long flags, loff_t size)\n{\n\treturn (flags & VM_ACCOUNT)?\n\t\tsecurity_vm_enough_memory(VM_ACCT(size)): 0;\n}',
#   'graph_idx': 12576,
#   'vul': 1,
#   'id': 13499},
#  {'cve': 'CVE-2022-43945',
#   'cwe_list': ['CWE-770'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'f90497a16e434c2211c66e3de8e77b17868382b8',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=f90497a16e434c2211c66e3de8e77b17868382b8',
#   'func': 'static __be32 nfsd4_decode_secinfo_no_name(struct nfsd4_compoundargs *argp,\n\t\t\t\t\t   struct nfsd4_secinfo_no_name *sin)\n{\n\tif (xdr_stream_decode_u32(argp->xdr, &sin->sin_style) < 0)\n\t\treturn nfserr_bad_xdr;\n\treturn nfs_ok;\n}',
#   'graph_idx': 410888,
#   'vul': 1,
#   'id': 31201},
#  {'cve': 'CVE-2022-43945',
#   'cwe_list': ['CWE-770'],
#   'repo_name': 'torvalds/linux',
#   'commit_hash': 'f90497a16e434c2211c66e3de8e77b17868382b8',
#   'git_url': 'https://git.kernel.org/pub/scm/linux/kernel/git/torvalds/linux.git/commit/?id=f90497a16e434c2211c66e3de8e77b17868382b8',
#   'func': 'static void nfsd4_close_open_stateid(struct nfs4_ol_stateid *s)\n{\n\tstruct nfs4_client *clp = s->st_stid.sc_client;\n\tbool unhashed;\n\tLIST_HEAD(reaplist);\n\n\tspin_lock(&clp->cl_lock);\n\tunhashed = unhash_open_stateid(s, &reaplist);\n\n\tif (clp->cl_minorversion) {\n\t\tif (unhashed)\n\t\t\tput_ol_stateid_locked(s, &reaplist);\n\t\tspin_unlock(&clp->cl_lock);\n\t\tfree_ol_stateid_reaplist(&reaplist);\n\t} else {\n\t\tspin_unlock(&clp->cl_lock);\n\t\tfree_ol_stateid_reaplist(&reaplist);\n\t\tif (unhashed)\n\t\t\tmove_to_close_lru(s, clp->net);\n\t}\n}',
#   'graph_idx': 410487,
#   'vul': 1,
#   'id': 16540},
#  {'cve': 'CVE-2019-3552',
#   'cwe_list': ['CWE-755'],
#   'repo_name': 'facebook/fbthrift',
#   'commit_hash': 'c5d6e07588cd03061bc54d451a7fa6e84883d62b',
#   'git_url': 'https://github.com/facebook/fbthrift/commit/c5d6e07588cd03061bc54d451a7fa6e84883d62b',
#   'func': 'static bool isEqual(const folly::IOBuf& lhs, const folly::IOBuf& rhs) {\n    return folly::IOBufEqualTo{}(lhs, rhs);\n  }',
#   'graph_idx': 250968,
#   'vul': 0,
#   'id': 29432},
#  {'cve': 'CVE-2016-2844',
#   'cwe_list': ['CWE-20'],
#   'repo_name': 'chromium',
#   'commit_hash': '231476fd47544d2f9d9f26920ddc821c16e976c8',
#   'git_url': 'https://chromium.googlesource.com/chromium/src/+/231476fd47544d2f9d9f26920ddc821c16e976c8',
#   'func': 'LayoutRect LayoutBlock::logicalRectToPhysicalRect(const LayoutPoint& rootBlockPhysicalPosition, const LayoutRect& logicalRect) const\n{\n    LayoutRect result;\n    if (isHorizontalWritingMode())\n        result = logicalRect;\n    else\n        result = LayoutRect(logicalRect.y(), logicalRect.x(), logicalRect.height(), logicalRect.width());\n    flipForWritingMode(result);\n    result.moveBy(rootBlockPhysicalPosition);\n    return result;\n}',
#   'graph_idx': 109357,
#   'vul': 0,
#   'id': 38441},
#  {'cve': 'CVE-2022-33746',
#   'cwe_list': ['CWE-400'],
#   'repo_name': 'xen-project/xen',
#   'commit_hash': 'ff600a8cf8e36f8ecbffecf96a035952e022ab87',
#   'git_url': 'https://github.com/xen-project/xen/commit/ff600a8cf8e36f8ecbffecf96a035952e022ab87',
#   'func': 'static struct page_info *hap_alloc(struct domain *d)\n{\n    struct page_info *pg;\n\n    ASSERT(paging_locked_by_me(d));\n\n    if ( unlikely(d->is_dying) )\n        return NULL;\n\n    pg = page_list_remove_head(&d->arch.paging.hap.freelist);\n    if ( unlikely(!pg) )\n        return NULL;\n\n    d->arch.paging.hap.free_pages--;\n\n    clear_domain_page(page_to_mfn(pg));\n\n    return pg;\n}',
#   'graph_idx': 401296,
#   'vul': 0,
#   'id': 4673},
#  {'cve': 'CVE-2018-19044',
#   'cwe_list': ['CWE-59'],
#   'repo_name': 'acassen/keepalived',
#   'commit_hash': '04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'git_url': 'https://github.com/acassen/keepalived/commit/04f2d32871bb3b11d7dc024039952f2fe2750306',
#   'func': 'static gchar*\nread_file(gchar* filepath)\n{\n\tFILE * f;\n\tsize_t length;\n\tgchar *ret = NULL;\n\n\tf = fopen(filepath, "rb");\n\tif (f) {\n\t\tfseek(f, 0, SEEK_END);\n\t\tlength = (size_t)ftell(f);\n\t\tfseek(f, 0, SEEK_SET);\n\n\t\t/* We can\'t use MALLOC since it isn\'t thread safe */\n\t\tret = MALLOC(length + 1);\n\t\tif (ret) {\n\t\t\tif (fread(ret, length, 1, f) != 1) {\n\t\t\t\tlog_message(LOG_INFO, "Failed to read all of %s", filepath);\n\t\t\t}\n\t\t\tret[length] = \'\\0\';\n\t\t}\n\t\telse\n\t\t\tlog_message(LOG_INFO, "Unable to read Dbus file %s", filepath);\n\n\t\tfclose(f);\n\t}\n\treturn ret;\n}',
#   'graph_idx': 238502,
#   'vul': 1,
#   'id': 36730},
#  {'cve': 'CVE-2016-3760',
#   'cwe_list': ['CWE-362', 'CWE-20'],
#   'repo_name': 'android',
#   'commit_hash': '37c88107679d36c419572732b4af6e18bb2f7dce',
#   'git_url': 'https://android.googlesource.com/platform/system/bt/+/37c88107679d36c419572732b4af6e18bb2f7dce',
#   'func': 'bool adapter_enable_disable() {\n  int error;\n\n  CALL_AND_WAIT(error = bt_interface->enable(), adapter_state_changed);\n  TASSERT(error == BT_STATUS_SUCCESS, "Error enabling Bluetooth: %d", error);\n  TASSERT(adapter_get_state() == BT_STATE_ON, "Adapter did not turn on.");\n\n  CALL_AND_WAIT(error = bt_interface->disable(), adapter_state_changed);\n  TASSERT(error == BT_STATUS_SUCCESS, "Error disabling Bluetooth: %d", error);\n  TASSERT(adapter_get_state() == BT_STATE_OFF, "Adapter did not turn off.");\n\n  return true;\n}',
#   'graph_idx': 131529,
#   'vul': 1,
#   'id': 24449}]

# %%
generation_config =  GenerationConfig(
    max_new_tokens=512,
    temperature=0.7,
    top_p=0.9,
    top_k=50,
    # do_sample=True,
    # eos_token_id=tokenizer.eos_token_id,
    # bos_token_id=tokenizer.bos_token_id,
    # pad_token_id=model.generation_config.pad_token_id,
    # repetition_penalty=1.1
)

prompt_templates = [
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable, I will give you a function, answer `yes` if the function is vulnerable, answer `no` if there is no vulnerability, no other information needs to be output. The first function is

$func""",
    """
I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, answer "yes" if the function is vulnerable, answer "no" if there is no vulnerability, no other information needs to be output.
$func
    """,
    """
Takes a function as input and outputs "yes" if the function is vulnerable and "no" if it is not.
$func
    """,
    """
takes a function as input and outputs "yes" if the function is vulnerable and "no" if it is not. Please note that to determine whether a function is vulnerable, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks. You should pay particular attention to any input or output processing, file handling, and network communication.
$func
    """,
    """As a vulnerability detector, your goal is to determine whether a given function is vulnerable. You will be provided with a function and your task is to identify whether it contains a vulnerability. "return 1" if the function is vulnerable, "return 0" if there is no vulnerability.
$func
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks.

$func

Is there any vulnerability in the above code? Answer "yes" or "no"
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks.

$func

Is there any vulnerability in the above code?
"return 1" if the function is vulnerable, "return 0" if there is no vulnerability.
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks. Answer "yes" if the function is vulnerable, answer "no" if there is no vulnerability, fill answer in #vulnerable

# function
$func

# vulnerable(yes or no)
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks. Output "yes" if the function is vulnerable, output "no" if there is no vulnerability.

Input:
$func

Output:
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks. Output "yes" if the function is vulnerable, output "no" if there is no vulnerability.

$func

The answer (Yes or No) is
    """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks.
1. If the function is vulnerable, return Yes.
2. If the function is not vulnerable, return No.

$func
    """,
    """As a vulnerability detector, your goal is to determine whether a given function is vulnerable. You will be provided with a function and your task is to identify whether it contains a vulnerability. Return "yes" if the function is vulnerable, or "no" if there is no vulnerability.

$func
Return """,
    """I want you to act as a vulnerability detector, your objective is to detect if a function is vulnerable. I will give you a function, you should analyze its code for potential security vulnerabilities, such as input validation issues, buffer overflow vulnerabilities, SQL injection vulnerabilities, and other security risks. Write a python function named "vulnerable" if the function is vulnerable, or "non_vulnerable" if there is no vulnerability.

$func
    """
]

def prompt_postprocessing(model_name:str,prompt:str):
    if model_name == "WizardLM/WizardLM-7B-V1.0":
        return f"""{prompt}

### Response:
"""
    assert False


for prompt_id,prompt_template in enumerate(prompt_templates):
    llm_result = []
    save_dir = Path(f"result/zero_shot//{model_name.replace('/','-')}")
    save_dir.mkdir(parents=True,exist_ok=True)
    f = open( save_dir /f'prompt_{prompt_id}.txt',mode='w')
    f.write('*'* 40 + f'{"Prompt Template":^20}' +  '*' * 40 + '\n')
    f.write(prompt_template)
    f.write('\n\n')

    for test_id,test_set_item in enumerate(tqdm(balanced_small_test_set.to_dict('records'))):
        func = test_set_item['func']
        vul = test_set_item['vul']
        prompt = Template(prompt_template).substitute(func = func)
        prompt = prompt_postprocessing(model_name,prompt)
        x = tokenizer(prompt,return_tensors='pt').to('cuda')
        y = model.generate(**x,generation_config=generation_config,eos_token_id = tokenizer.eos_token_id,
                           pad_token_id=tokenizer.eos_token_id)
        decode_result = tokenizer.decode(y[0], skip_special_tokens=True)


        f.write('\n' + '*'* 40 + f'{test_id:^20}' +  '*' * 40 + '\n')
        f.write(prompt)
        f.write('\n' + '*'* 40 + f'{"Generate":^20}' +  '*' * 40 + '\n')
        f.write(decode_result)
        f.write('\n' + '*'* 40 + f'{"END":^20}' +  '*' * 40 + '\n' + '*'*100 )
        f.write('\n'*5)

    f.close()


# prompts = ["Write a python function sum two number", "write a multiprocess function"]
#
# for i in range(100):
#     x = tokenizer(prompts[i % 2],return_tensors='pt').to('cuda')
#     y = model.generate(**x,generation_config=generation_config,eos_token_id = tokenizer.eos_token_id,bos_token_id=tokenizer.bos_token_id )
#     print(tokenizer.batch_decode(y, skip_special_tokens=True))
# Out:
# 100%|██████████| 200/200 [20:18<00:00,  6.09s/it]
# 100%|██████████| 200/200 [11:56<00:00,  3.58s/it]
# 100%|██████████| 200/200 [15:23<00:00,  4.62s/it]
# 100%|██████████| 200/200 [13:29<00:00,  4.05s/it]
# 100%|██████████| 200/200 [17:34<00:00,  5.27s/it]
# 100%|██████████| 200/200 [13:47<00:00,  4.14s/it]
# 100%|██████████| 200/200 [16:24<00:00,  4.92s/it]
# 100%|██████████| 200/200 [22:29<00:00,  6.75s/it]
# 100%|██████████| 200/200 [20:42<00:00,  6.21s/it]
# 100%|██████████| 200/200 [18:01<00:00,  5.41s/it]
# 100%|██████████| 200/200 [13:47<00:00,  4.14s/it]
# 100%|██████████| 200/200 [17:46<00:00,  5.33s/it]
# 100%|██████████| 200/200 [21:05<00:00,  6.33s/it]

# %%
x=20
print(f'{x:^20}')
# Out:
#          20
